# %%
import os
import torch
from PIL import Image
import torchvision.transforms as T
import json

# Define the path to your furniture folder
downloads_path = os.path.expanduser("~/Downloads/furniture")  # Adjust for Windows: r"C:\Users\<YourUsername>\Downloads\furniture"

# Get list of image paths from all subfolders
image_paths = []
subfolders = ["cabinets,cupboards,etc", "chair", "fridge", "table", "tv"]
for subfolder in subfolders:
    subfolder_path = os.path.join(downloads_path, subfolder)
    for fname in os.listdir(subfolder_path):
        if fname.lower().endswith((".jpg", ".png", ".jpeg")):
            image_paths.append(os.path.join(subfolder_path, fname))

# Load annotations (assuming COCO JSON format)
annotations_path = os.path.join(downloads_path, "annotations.json")
with open(annotations_path, "r") as f:
    coco_data = json.load(f)

# Map annotations to images
annotations = []
for img_path in image_paths:
    img_name = os.path.basename(img_path)
    img_id = next((item["id"] for item in coco_data["images"] if item["file_name"] == img_name), None)
    if img_id is None:
        print(f"Warning: No annotation found for {img_name}")
        continue
    img_annotations = [ann for ann in coco_data["annotations"] if ann["image_id"] == img_id]
    boxes = [[ann["bbox"][0], ann["bbox"][1], ann["bbox"][0] + ann["bbox"][2], ann["bbox"][1] + ann["bbox"][3]] for ann in img_annotations]
    labels = [ann["category_id"] for ann in img_annotations]
    annotations.append({
        "boxes": boxes,  # Format: [[xmin, ymin, xmax, ymax], ...]
        "labels": labels  # Class labels
    })

# Filter image_paths to only include images with annotations
image_paths = [img_path for img_path, ann in zip(image_paths, annotations) if ann["boxes"] and ann["labels"]]

# Define the load_dataset function
def load_dataset(image_paths, annotations):
    dataset = []
    transform = T.ToTensor()  # Convert PIL image to tensor
    for img_path, ann in zip(image_paths, annotations):
        img = Image.open(img_path).convert("RGB")
        img_tensor = transform(img)
        target = {
            "boxes": torch.tensor(ann["boxes"], dtype=torch.float32),
            "labels": torch.tensor(ann["labels"], dtype=torch.int64)
        }
        dataset.append((img_tensor, target))
    return dataset

# Create dataset and DataLoader
from torch.utils.data import DataLoader
dataset = load_dataset(image_paths, annotations)
dataloader = DataLoader(dataset, batch_size=4, shuffle=True, collate_fn=lambda x: tuple(zip(*x)))

print(f"Loaded {len(dataset)} images with annotations.")
# Out:
# Warning: No annotation found for image_2341.jpeg
# Warning: No annotation found for image_947.jpeg
# Warning: No annotation found for image_1994.jpeg
# Warning: No annotation found for image_2711.jpeg
# Warning: No annotation found for image_1097.jpeg
# Warning: No annotation found for image_414.jpeg
# Warning: No annotation found for image_101.jpeg
# Warning: No annotation found for image_1428.jpeg
# Warning: No annotation found for image_551.jpeg
# Warning: No annotation found for image_1582.jpeg
# Warning: No annotation found for image_1078.jpeg
# Warning: No annotation found for image_802.jpeg
# Warning: No annotation found for image_2204.jpeg
# Warning: No annotation found for image_2654.jpeg
# Warning: No annotation found for image_2984.jpeg
# Warning: No annotation found for image_678.jpeg
# Warning: No annotation found for image_382.jpeg
# Warning: No annotation found for image_1351.jpeg
# Warning: No annotation found for image_228.jpeg
# Warning: No annotation found for image_1701.jpeg
# Warning: No annotation found for image_2087.jpeg
# Warning: No annotation found for image_33.jpeg
# Warning: No annotation found for image_2438.jpeg
# Warning: No annotation found for image_2068.jpeg
# Warning: No annotation found for image_2592.jpeg
# Warning: No annotation found for image_1214.jpeg
# Warning: No annotation found for image_697.jpeg
# Warning: No annotation found for image_1644.jpeg
# Warning: No annotation found for image_443.jpeg
# Warning: No annotation found for image_1490.jpeg
# Warning: No annotation found for image_1869.jpeg
# Warning: No annotation found for image_2746.jpeg
# Warning: No annotation found for image_910.jpeg
# Warning: No annotation found for image_2316.jpeg
# Warning: No annotation found for image_2603.jpeg
# Warning: No annotation found for image_2253.jpeg
# Warning: No annotation found for image_855.jpeg
# Warning: No annotation found for image_1886.jpeg
# Warning: No annotation found for image_506.jpeg
# Warning: No annotation found for image_156.jpeg
# Warning: No annotation found for image_1185.jpeg
# Warning: No annotation found for image_64.jpeg
# Warning: No annotation found for image_2480.jpeg
# Warning: No annotation found for image_785.jpeg
# Warning: No annotation found for image_1756.jpeg
# Warning: No annotation found for image_2879.jpeg
# Warning: No annotation found for image_1306.jpeg
# Warning: No annotation found for image_1613.jpeg
# Warning: No annotation found for image_2896.jpeg
# Warning: No annotation found for image_290.jpeg
# Warning: No annotation found for image_1243.jpeg
# Warning: No annotation found for image_2195.jpeg
# Warning: No annotation found for image_2300.jpeg
# Warning: No annotation found for image_906.jpeg
# Warning: No annotation found for image_2750.jpeg
# Warning: No annotation found for image_1486.jpeg
# Warning: No annotation found for image_455.jpeg
# Warning: No annotation found for image_1193.jpeg
# Warning: No annotation found for image_140.jpeg
# Warning: No annotation found for image_1469.jpeg
# Warning: No annotation found for image_510.jpeg
# Warning: No annotation found for image_1039.jpeg
# Warning: No annotation found for image_1890.jpeg
# Warning: No annotation found for image_843.jpeg
# Warning: No annotation found for image_2245.jpeg
# Warning: No annotation found for image_2615.jpeg
# Warning: No annotation found for image_639.jpeg
# Warning: No annotation found for image_1310.jpeg
# Warning: No annotation found for image_269.jpeg
# Warning: No annotation found for image_1740.jpeg
# Warning: No annotation found for image_793.jpeg
# Warning: No annotation found for image_72.jpeg
# Warning: No annotation found for image_2496.jpeg
# Warning: No annotation found for image_2479.jpeg
# Warning: No annotation found for image_2183.jpeg
# Warning: No annotation found for image_2029.jpeg
# Warning: No annotation found for image_1255.jpeg
# Warning: No annotation found for image_286.jpeg
# Warning: No annotation found for image_2880.jpeg
# Warning: No annotation found for image_1605.jpeg
# Warning: No annotation found for image_402.jpeg
# Warning: No annotation found for image_1081.jpeg
# Warning: No annotation found for image_2707.jpeg
# Warning: No annotation found for image_1828.jpeg
# Warning: No annotation found for image_1982.jpeg
# Warning: No annotation found for image_951.jpeg
# Warning: No annotation found for image_2357.jpeg
# Warning: No annotation found for image_2642.jpeg
# Warning: No annotation found for image_2212.jpeg
# Warning: No annotation found for image_814.jpeg
# Warning: No annotation found for image_1594.jpeg
# Warning: No annotation found for image_547.jpeg
# Warning: No annotation found for image_117.jpeg
# Warning: No annotation found for image_25.jpeg
# Warning: No annotation found for image_2091.jpeg
# Warning: No annotation found for image_2838.jpeg
# Warning: No annotation found for image_1717.jpeg
# Warning: No annotation found for image_1347.jpeg
# Warning: No annotation found for image_394.jpeg
# Warning: No annotation found for image_2992.jpeg
# Warning: No annotation found for image_1652.jpeg
# Warning: No annotation found for image_681.jpeg
# Warning: No annotation found for image_1202.jpeg
# Warning: No annotation found for image_2584.jpeg
# Warning: No annotation found for image_2639.jpeg
# Warning: No annotation found for image_1916.jpeg
# Warning: No annotation found for image_2269.jpeg
# Warning: No annotation found for image_2793.jpeg
# Warning: No annotation found for image_1015.jpeg
# Warning: No annotation found for image_1445.jpeg
# Warning: No annotation found for image_496.jpeg
# Warning: No annotation found for image_479.jpeg
# Warning: No annotation found for image_1150.jpeg
# Warning: No annotation found for image_183.jpeg
# Warning: No annotation found for image_1500.jpeg
# Warning: No annotation found for image_2286.jpeg
# Warning: No annotation found for image_1853.jpeg
# Warning: No annotation found for image_880.jpeg
# Warning: No annotation found for image_300.jpeg
# Warning: No annotation found for image_2906.jpeg
# Warning: No annotation found for image_1629.jpeg
# Warning: No annotation found for image_1783.jpeg
# Warning: No annotation found for image_750.jpeg
# Warning: No annotation found for image_1279.jpeg
# Warning: No annotation found for image_2005.jpeg
# Warning: No annotation found for image_2455.jpeg
# Warning: No annotation found for image_2140.jpeg
# Warning: No annotation found for image_2510.jpeg
# Warning: No annotation found for image_2843.jpeg
# Warning: No annotation found for image_1296.jpeg
# Warning: No annotation found for image_245.jpeg
# Warning: No annotation found for image_615.jpeg
# Warning: No annotation found for image_1412.jpeg
# Warning: No annotation found for image_1042.jpeg
# Warning: No annotation found for image_838.jpeg
# Warning: No annotation found for image_2394.jpeg
# Warning: No annotation found for image_1941.jpeg
# Warning: No annotation found for image_992.jpeg
# Warning: No annotation found for image_2681.jpeg
# Warning: No annotation found for image_1804.jpeg
# Warning: No annotation found for image_1557.jpeg
# Warning: No annotation found for image_584.jpeg
# Warning: No annotation found for image_1107.jpeg
# Warning: No annotation found for image_2402.jpeg
# Warning: No annotation found for image_2052.jpeg
# Warning: No annotation found for image_707.jpeg
# Warning: No annotation found for image_2951.jpeg
# Warning: No annotation found for image_1384.jpeg
# Warning: No annotation found for image_357.jpeg
# Warning: No annotation found for image_1691.jpeg
# Warning: No annotation found for image_642.jpeg
# Warning: No annotation found for image_212.jpeg
# Warning: No annotation found for image_2814.jpeg
# Warning: No annotation found for image_2547.jpeg
# Warning: No annotation found for image_2117.jpeg
# Warning: No annotation found for image_984.jpeg
# Warning: No annotation found for image_1957.jpeg
# Warning: No annotation found for image_2678.jpeg
# Warning: No annotation found for image_2382.jpeg
# Warning: No annotation found for image_2228.jpeg
# Warning: No annotation found for image_1054.jpeg
# Warning: No annotation found for image_1404.jpeg
# Warning: No annotation found for image_438.jpeg
# Warning: No annotation found for image_1111.jpeg
# Warning: No annotation found for image_592.jpeg
# Warning: No annotation found for image_1541.jpeg
# Warning: No annotation found for image_1812.jpeg
# Warning: No annotation found for image_2697.jpeg
# Warning: No annotation found for image_341.jpeg
# Warning: No annotation found for image_1392.jpeg
# Warning: No annotation found for image_1668.jpeg
# Warning: No annotation found for image_2947.jpeg
# Warning: No annotation found for image_711.jpeg
# Warning: No annotation found for image_1238.jpeg
# Warning: No annotation found for image_2044.jpeg
# Warning: No annotation found for image_2414.jpeg
# Warning: No annotation found for image_2101.jpeg
# Warning: No annotation found for image_2551.jpeg
# Warning: No annotation found for image_2802.jpeg
# Warning: No annotation found for image_204.jpeg
# Warning: No annotation found for image_654.jpeg
# Warning: No annotation found for image_1687.jpeg
# Warning: No annotation found for image_480.jpeg
# Warning: No annotation found for image_1453.jpeg
# Warning: No annotation found for image_1003.jpeg
# Warning: No annotation found for image_2785.jpeg
# Warning: No annotation found for image_879.jpeg
# Warning: No annotation found for image_1900.jpeg
# Warning: No annotation found for image_896.jpeg
# Warning: No annotation found for image_1845.jpeg
# Warning: No annotation found for image_2290.jpeg
# Warning: No annotation found for image_1516.jpeg
# Warning: No annotation found for image_195.jpeg
# Warning: No annotation found for image_1146.jpeg
# Warning: No annotation found for image_2443.jpeg
# Warning: No annotation found for image_2013.jpeg
# Warning: No annotation found for image_746.jpeg
# Warning: No annotation found for image_1795.jpeg
# Warning: No annotation found for image_2910.jpeg
# Warning: No annotation found for image_316.jpeg
# Warning: No annotation found for image_603.jpeg
# Warning: No annotation found for image_253.jpeg
# Warning: No annotation found for image_1280.jpeg
# Warning: No annotation found for image_2855.jpeg
# Warning: No annotation found for image_2506.jpeg
# Warning: No annotation found for image_48.jpeg
# Warning: No annotation found for image_2156.jpeg
# Warning: No annotation found for image_2121.jpeg
# Warning: No annotation found for image_2571.jpeg
# Warning: No annotation found for image_2822.jpeg
# Warning: No annotation found for image_224.jpeg
# Warning: No annotation found for image_674.jpeg
# Warning: No annotation found for image_2988.jpeg
# Warning: No annotation found for image_361.jpeg
# Warning: No annotation found for image_1648.jpeg
# Warning: No annotation found for image_2967.jpeg
# Warning: No annotation found for image_731.jpeg
# Warning: No annotation found for image_1218.jpeg
# Warning: No annotation found for image_2064.jpeg
# Warning: No annotation found for image_6.jpeg
# Warning: No annotation found for image_2434.jpeg
# Warning: No annotation found for image_418.jpeg
# Warning: No annotation found for image_1131.jpeg
# Warning: No annotation found for image_1561.jpeg
# Warning: No annotation found for image_1832.jpeg
# Warning: No annotation found for image_1998.jpeg
# Warning: No annotation found for image_1977.jpeg
# Warning: No annotation found for image_2658.jpeg
# Warning: No annotation found for image_2208.jpeg
# Warning: No annotation found for image_1074.jpeg
# Warning: No annotation found for image_1424.jpeg
# Warning: No annotation found for image_623.jpeg
# Warning: No annotation found for image_273.jpeg
# Warning: No annotation found for image_2875.jpeg
# Warning: No annotation found for image_789.jpeg
# Warning: No annotation found for image_2526.jpeg
# Warning: No annotation found for image_68.jpeg
# Warning: No annotation found for image_2176.jpeg
# Warning: No annotation found for image_87.jpeg
# Warning: No annotation found for image_2463.jpeg
# Warning: No annotation found for image_2199.jpeg
# Warning: No annotation found for image_2033.jpeg
# Warning: No annotation found for image_766.jpeg
# Warning: No annotation found for image_2930.jpeg
# Warning: No annotation found for image_336.jpeg
# Warning: No annotation found for image_1865.jpeg
# Warning: No annotation found for image_1536.jpeg
# Warning: No annotation found for image_1166.jpeg
# Warning: No annotation found for image_1189.jpeg
# Warning: No annotation found for image_1473.jpeg
# Warning: No annotation found for image_1023.jpeg
# Warning: No annotation found for image_859.jpeg
# Warning: No annotation found for image_1920.jpeg
# Warning: No annotation found for image_2160.jpeg
# Warning: No annotation found for image_2530.jpeg
# Warning: No annotation found for image_2863.jpeg
# Warning: No annotation found for image_265.jpeg
# Warning: No annotation found for image_635.jpeg
# Warning: No annotation found for image_320.jpeg
# Warning: No annotation found for image_2926.jpeg
# Warning: No annotation found for image_1609.jpeg
# Warning: No annotation found for image_770.jpeg
# Warning: No annotation found for image_1259.jpeg
# Warning: No annotation found for image_2025.jpeg
# Warning: No annotation found for image_91.jpeg
# Warning: No annotation found for image_2475.jpeg
# Warning: No annotation found for image_459.jpeg
# Warning: No annotation found for image_1170.jpeg
# Warning: No annotation found for image_1520.jpeg
# Warning: No annotation found for image_1873.jpeg
# Warning: No annotation found for image_2619.jpeg
# Warning: No annotation found for image_1936.jpeg
# Warning: No annotation found for image_2249.jpeg
# Warning: No annotation found for image_1035.jpeg
# Warning: No annotation found for image_1465.jpeg
# Warning: No annotation found for image_662.jpeg
# Warning: No annotation found for image_398.jpeg
# Warning: No annotation found for image_232.jpeg
# Warning: No annotation found for image_2834.jpeg
# Warning: No annotation found for image_2567.jpeg
# Warning: No annotation found for image_29.jpeg
# Warning: No annotation found for image_2137.jpeg
# Warning: No annotation found for image_2422.jpeg
# Warning: No annotation found for image_2072.jpeg
# Warning: No annotation found for image_2588.jpeg
# Warning: No annotation found for image_727.jpeg
# Warning: No annotation found for image_2971.jpeg
# Warning: No annotation found for image_377.jpeg
# Warning: No annotation found for image_1824.jpeg
# Warning: No annotation found for image_1577.jpeg
# Warning: No annotation found for image_1127.jpeg
# Warning: No annotation found for image_1432.jpeg
# Warning: No annotation found for image_1598.jpeg
# Warning: No annotation found for image_1062.jpeg
# Warning: No annotation found for image_818.jpeg
# Warning: No annotation found for image_1961.jpeg
# Warning: No annotation found for image_2459.jpeg
# Warning: No annotation found for image_2009.jpeg
# Warning: No annotation found for image_1275.jpeg
# Warning: No annotation found for image_1625.jpeg
# Warning: No annotation found for image_619.jpeg
# Warning: No annotation found for image_1330.jpeg
# Warning: No annotation found for image_249.jpeg
# Warning: No annotation found for image_1760.jpeg
# Warning: No annotation found for image_52.jpeg
# Warning: No annotation found for image_160.jpeg
# Warning: No annotation found for image_1449.jpeg
# Warning: No annotation found for image_530.jpeg
# Warning: No annotation found for image_1019.jpeg
# Warning: No annotation found for image_863.jpeg
# Warning: No annotation found for image_2265.jpeg
# Warning: No annotation found for image_2635.jpeg
# Warning: No annotation found for image_2320.jpeg
# Warning: No annotation found for image_926.jpeg
# Warning: No annotation found for image_2770.jpeg
# Warning: No annotation found for image_475.jpeg
# Warning: No annotation found for image_1388.jpeg
# Warning: No annotation found for image_1672.jpeg
# Warning: No annotation found for image_1222.jpeg
# Warning: No annotation found for image_2818.jpeg
# Warning: No annotation found for image_1737.jpeg
# Warning: No annotation found for image_1367.jpeg
# Warning: No annotation found for image_2662.jpeg
# Warning: No annotation found for image_2398.jpeg
# Warning: No annotation found for image_2232.jpeg
# Warning: No annotation found for image_834.jpeg
# Warning: No annotation found for image_567.jpeg
# Warning: No annotation found for image_137.jpeg
# Warning: No annotation found for image_422.jpeg
# Warning: No annotation found for image_588.jpeg
# Warning: No annotation found for image_2727.jpeg
# Warning: No annotation found for image_1808.jpeg
# Warning: No annotation found for image_971.jpeg
# Warning: No annotation found for image_2377.jpeg
# Warning: No annotation found for image_2418.jpeg
# Warning: No annotation found for image_2048.jpeg
# Warning: No annotation found for image_1234.jpeg
# Warning: No annotation found for image_1664.jpeg
# Warning: No annotation found for image_658.jpeg
# Warning: No annotation found for image_1371.jpeg
# Warning: No annotation found for image_208.jpeg
# Warning: No annotation found for image_1721.jpeg
# Warning: No annotation found for image_13.jpeg
# Warning: No annotation found for image_121.jpeg
# Warning: No annotation found for image_1408.jpeg
# Warning: No annotation found for image_571.jpeg
# Warning: No annotation found for image_1058.jpeg
# Warning: No annotation found for image_822.jpeg
# Warning: No annotation found for image_2224.jpeg
# Warning: No annotation found for image_2674.jpeg
# Warning: No annotation found for image_988.jpeg
# Warning: No annotation found for image_2361.jpeg
# Warning: No annotation found for image_967.jpeg
# Warning: No annotation found for image_2731.jpeg
# Warning: No annotation found for image_434.jpeg
# Warning: No annotation found for image_1633.jpeg
# Warning: No annotation found for image_1799.jpeg
# Warning: No annotation found for image_1263.jpeg
# Warning: No annotation found for image_44.jpeg
# Warning: No annotation found for image_1776.jpeg
# Warning: No annotation found for image_2859.jpeg
# Warning: No annotation found for image_1326.jpeg
# Warning: No annotation found for image_2623.jpeg
# Warning: No annotation found for image_2273.jpeg
# Warning: No annotation found for image_875.jpeg
# Warning: No annotation found for image_2789.jpeg
# Warning: No annotation found for image_526.jpeg
# Warning: No annotation found for image_176.jpeg
# Warning: No annotation found for image_463.jpeg
# Warning: No annotation found for image_199.jpeg
# Warning: No annotation found for image_1849.jpeg
# Warning: No annotation found for image_2766.jpeg
# Warning: No annotation found for image_930.jpeg
# Warning: No annotation found for image_2336.jpeg
# Warning: No annotation found for image_2622.jpeg
# Warning: No annotation found for image_2272.jpeg
# Warning: No annotation found for image_2788.jpeg
# Warning: No annotation found for image_874.jpeg
# Warning: No annotation found for image_527.jpeg
# Warning: No annotation found for image_177.jpeg
# Warning: No annotation found for image_462.jpeg
# Warning: No annotation found for image_198.jpeg
# Warning: No annotation found for image_1848.jpeg
# Warning: No annotation found for image_2767.jpeg
# Warning: No annotation found for image_931.jpeg
# Warning: No annotation found for image_2337.jpeg
# Warning: No annotation found for image_1632.jpeg
# Warning: No annotation found for image_1798.jpeg
# Warning: No annotation found for image_1262.jpeg
# Warning: No annotation found for image_45.jpeg
# Warning: No annotation found for image_1777.jpeg
# Warning: No annotation found for image_2858.jpeg
# Warning: No annotation found for image_1327.jpeg
# Warning: No annotation found for image_120.jpeg
# Warning: No annotation found for image_1409.jpeg
# Warning: No annotation found for image_570.jpeg
# Warning: No annotation found for image_1059.jpeg
# Warning: No annotation found for image_823.jpeg
# Warning: No annotation found for image_2225.jpeg
# Warning: No annotation found for image_989.jpeg
# Warning: No annotation found for image_2675.jpeg
# Warning: No annotation found for image_2360.jpeg
# Warning: No annotation found for image_966.jpeg
# Warning: No annotation found for image_2730.jpeg
# Warning: No annotation found for image_435.jpeg
# Warning: No annotation found for image_2419.jpeg
# Warning: No annotation found for image_2049.jpeg
# Warning: No annotation found for image_1235.jpeg
# Warning: No annotation found for image_1665.jpeg
# Warning: No annotation found for image_659.jpeg
# Warning: No annotation found for image_1370.jpeg
# Warning: No annotation found for image_209.jpeg
# Warning: No annotation found for image_1720.jpeg
# Warning: No annotation found for image_12.jpeg
# Warning: No annotation found for image_2663.jpeg
# Warning: No annotation found for image_2399.jpeg
# Warning: No annotation found for image_2233.jpeg
# Warning: No annotation found for image_835.jpeg
# Warning: No annotation found for image_566.jpeg
# Warning: No annotation found for image_136.jpeg
# Warning: No annotation found for image_423.jpeg
# Warning: No annotation found for image_589.jpeg
# Warning: No annotation found for image_2726.jpeg
# Warning: No annotation found for image_1809.jpeg
# Warning: No annotation found for image_970.jpeg
# Warning: No annotation found for image_2376.jpeg
# Warning: No annotation found for image_1389.jpeg
# Warning: No annotation found for image_1673.jpeg
# Warning: No annotation found for image_1223.jpeg
# Warning: No annotation found for image_2819.jpeg
# Warning: No annotation found for image_1736.jpeg
# Warning: No annotation found for image_1366.jpeg
# Warning: No annotation found for image_161.jpeg
# Warning: No annotation found for image_1448.jpeg
# Warning: No annotation found for image_531.jpeg
# Warning: No annotation found for image_1018.jpeg
# Warning: No annotation found for image_862.jpeg
# Warning: No annotation found for image_2264.jpeg
# Warning: No annotation found for image_2634.jpeg
# Warning: No annotation found for image_2321.jpeg
# Warning: No annotation found for image_927.jpeg
# Warning: No annotation found for image_2771.jpeg
# Warning: No annotation found for image_474.jpeg
# Warning: No annotation found for image_2458.jpeg
# Warning: No annotation found for image_2008.jpeg
# Warning: No annotation found for image_1274.jpeg
# Warning: No annotation found for image_1624.jpeg
# Warning: No annotation found for image_618.jpeg
# Warning: No annotation found for image_1331.jpeg
# Warning: No annotation found for image_248.jpeg
# Warning: No annotation found for image_1761.jpeg
# Warning: No annotation found for image_53.jpeg
# Warning: No annotation found for image_1825.jpeg
# Warning: No annotation found for image_1576.jpeg
# Warning: No annotation found for image_1126.jpeg
# Warning: No annotation found for image_1433.jpeg
# Warning: No annotation found for image_1599.jpeg
# Warning: No annotation found for image_1063.jpeg
# Warning: No annotation found for image_819.jpeg
# Warning: No annotation found for image_1960.jpeg
# Warning: No annotation found for image_663.jpeg
# Warning: No annotation found for image_399.jpeg
# Warning: No annotation found for image_233.jpeg
# Warning: No annotation found for image_2835.jpeg
# Warning: No annotation found for image_2566.jpeg
# Warning: No annotation found for image_28.jpeg
# Warning: No annotation found for image_2136.jpeg
# Warning: No annotation found for image_2423.jpeg
# Warning: No annotation found for image_2073.jpeg
# Warning: No annotation found for image_2589.jpeg
# Warning: No annotation found for image_726.jpeg
# Warning: No annotation found for image_2970.jpeg
# Warning: No annotation found for image_376.jpeg
# Warning: No annotation found for image_458.jpeg
# Warning: No annotation found for image_1171.jpeg
# Warning: No annotation found for image_1521.jpeg
# Warning: No annotation found for image_1872.jpeg
# Warning: No annotation found for image_2618.jpeg
# Warning: No annotation found for image_1937.jpeg
# Warning: No annotation found for image_2248.jpeg
# Warning: No annotation found for image_1034.jpeg
# Warning: No annotation found for image_1464.jpeg
# Warning: No annotation found for image_2161.jpeg
# Warning: No annotation found for image_2531.jpeg
# Warning: No annotation found for image_2862.jpeg
# Warning: No annotation found for image_264.jpeg
# Warning: No annotation found for image_634.jpeg
# Warning: No annotation found for image_321.jpeg
# Warning: No annotation found for image_2927.jpeg
# Warning: No annotation found for image_1608.jpeg
# Warning: No annotation found for image_771.jpeg
# Warning: No annotation found for image_1258.jpeg
# Warning: No annotation found for image_2024.jpeg
# Warning: No annotation found for image_2474.jpeg
# Warning: No annotation found for image_90.jpeg
# Warning: No annotation found for image_1864.jpeg
# Warning: No annotation found for image_1537.jpeg
# Warning: No annotation found for image_1167.jpeg
# Warning: No annotation found for image_1188.jpeg
# Warning: No annotation found for image_1472.jpeg
# Warning: No annotation found for image_1022.jpeg
# Warning: No annotation found for image_858.jpeg
# Warning: No annotation found for image_1921.jpeg
# Warning: No annotation found for image_622.jpeg
# Warning: No annotation found for image_272.jpeg
# Warning: No annotation found for image_788.jpeg
# Warning: No annotation found for image_2874.jpeg
# Warning: No annotation found for image_2527.jpeg
# Warning: No annotation found for image_69.jpeg
# Warning: No annotation found for image_2177.jpeg
# Warning: No annotation found for image_2462.jpeg
# Warning: No annotation found for image_86.jpeg
# Warning: No annotation found for image_2198.jpeg
# Warning: No annotation found for image_2032.jpeg
# Warning: No annotation found for image_767.jpeg
# Warning: No annotation found for image_2931.jpeg
# Warning: No annotation found for image_337.jpeg
# Warning: No annotation found for image_419.jpeg
# Warning: No annotation found for image_1130.jpeg
# Warning: No annotation found for image_1560.jpeg
# Warning: No annotation found for image_1833.jpeg
# Warning: No annotation found for image_1999.jpeg
# Warning: No annotation found for image_1976.jpeg
# Warning: No annotation found for image_2659.jpeg
# Warning: No annotation found for image_2209.jpeg
# Warning: No annotation found for image_1075.jpeg
# Warning: No annotation found for image_1425.jpeg
# Warning: No annotation found for image_2120.jpeg
# Warning: No annotation found for image_2570.jpeg
# Warning: No annotation found for image_2823.jpeg
# Warning: No annotation found for image_225.jpeg
# Warning: No annotation found for image_2989.jpeg
# Warning: No annotation found for image_675.jpeg
# Warning: No annotation found for image_360.jpeg
# Warning: No annotation found for image_1649.jpeg
# Warning: No annotation found for image_2966.jpeg
# Warning: No annotation found for image_730.jpeg
# Warning: No annotation found for image_1219.jpeg
# Warning: No annotation found for image_7.jpeg
# Warning: No annotation found for image_2065.jpeg
# Warning: No annotation found for image_2435.jpeg
# Warning: No annotation found for image_2442.jpeg
# Warning: No annotation found for image_2012.jpeg
# Warning: No annotation found for image_1794.jpeg
# Warning: No annotation found for image_747.jpeg
# Warning: No annotation found for image_2911.jpeg
# Warning: No annotation found for image_317.jpeg
# Warning: No annotation found for image_602.jpeg
# Warning: No annotation found for image_1281.jpeg
# Warning: No annotation found for image_252.jpeg
# Warning: No annotation found for image_2854.jpeg
# Warning: No annotation found for image_2507.jpeg
# Warning: No annotation found for image_49.jpeg
# Warning: No annotation found for image_2157.jpeg
# Warning: No annotation found for image_1452.jpeg
# Warning: No annotation found for image_481.jpeg
# Warning: No annotation found for image_1002.jpeg
# Warning: No annotation found for image_878.jpeg
# Warning: No annotation found for image_2784.jpeg
# Warning: No annotation found for image_1901.jpeg
# Warning: No annotation found for image_1844.jpeg
# Warning: No annotation found for image_897.jpeg
# Warning: No annotation found for image_2291.jpeg
# Warning: No annotation found for image_1517.jpeg
# Warning: No annotation found for image_1147.jpeg
# Warning: No annotation found for image_194.jpeg
# Warning: No annotation found for image_1393.jpeg
# Warning: No annotation found for image_340.jpeg
# Warning: No annotation found for image_1669.jpeg
# Warning: No annotation found for image_2946.jpeg
# Warning: No annotation found for image_710.jpeg
# Warning: No annotation found for image_1239.jpeg
# Warning: No annotation found for image_2045.jpeg
# Warning: No annotation found for image_2415.jpeg
# Warning: No annotation found for image_2100.jpeg
# Warning: No annotation found for image_2550.jpeg
# Warning: No annotation found for image_2803.jpeg
# Warning: No annotation found for image_205.jpeg
# Warning: No annotation found for image_1686.jpeg
# Warning: No annotation found for image_655.jpeg
# Warning: No annotation found for image_1956.jpeg
# Warning: No annotation found for image_2679.jpeg
# Warning: No annotation found for image_985.jpeg
# Warning: No annotation found for image_2383.jpeg
# Warning: No annotation found for image_2229.jpeg
# Warning: No annotation found for image_1055.jpeg
# Warning: No annotation found for image_1405.jpeg
# Warning: No annotation found for image_439.jpeg
# Warning: No annotation found for image_1110.jpeg
# Warning: No annotation found for image_1540.jpeg
# Warning: No annotation found for image_593.jpeg
# Warning: No annotation found for image_1813.jpeg
# Warning: No annotation found for image_2696.jpeg
# Warning: No annotation found for image_2403.jpeg
# Warning: No annotation found for image_2053.jpeg
# Warning: No annotation found for image_706.jpeg
# Warning: No annotation found for image_2950.jpeg
# Warning: No annotation found for image_356.jpeg
# Warning: No annotation found for image_1385.jpeg
# Warning: No annotation found for image_643.jpeg
# Warning: No annotation found for image_1690.jpeg
# Warning: No annotation found for image_213.jpeg
# Warning: No annotation found for image_2815.jpeg
# Warning: No annotation found for image_2546.jpeg
# Warning: No annotation found for image_2116.jpeg
# Warning: No annotation found for image_1413.jpeg
# Warning: No annotation found for image_1043.jpeg
# Warning: No annotation found for image_839.jpeg
# Warning: No annotation found for image_2395.jpeg
# Warning: No annotation found for image_993.jpeg
# Warning: No annotation found for image_1940.jpeg
# Warning: No annotation found for image_2680.jpeg
# Warning: No annotation found for image_1805.jpeg
# Warning: No annotation found for image_585.jpeg
# Warning: No annotation found for image_1556.jpeg
# Warning: No annotation found for image_1106.jpeg
# Warning: No annotation found for image_301.jpeg
# Warning: No annotation found for image_2907.jpeg
# Warning: No annotation found for image_1628.jpeg
# Warning: No annotation found for image_751.jpeg
# Warning: No annotation found for image_1782.jpeg
# Warning: No annotation found for image_1278.jpeg
# Warning: No annotation found for image_2004.jpeg
# Warning: No annotation found for image_2454.jpeg
# Warning: No annotation found for image_2141.jpeg
# Warning: No annotation found for image_2511.jpeg
# Warning: No annotation found for image_2842.jpeg
# Warning: No annotation found for image_244.jpeg
# Warning: No annotation found for image_1297.jpeg
# Warning: No annotation found for image_614.jpeg
# Warning: No annotation found for image_2638.jpeg
# Warning: No annotation found for image_1917.jpeg
# Warning: No annotation found for image_2268.jpeg
# Warning: No annotation found for image_2792.jpeg
# Warning: No annotation found for image_1014.jpeg
# Warning: No annotation found for image_497.jpeg
# Warning: No annotation found for image_1444.jpeg
# Warning: No annotation found for image_478.jpeg
# Warning: No annotation found for image_182.jpeg
# Warning: No annotation found for image_1151.jpeg
# Warning: No annotation found for image_1501.jpeg
# Warning: No annotation found for image_2287.jpeg
# Warning: No annotation found for image_881.jpeg
# Warning: No annotation found for image_1852.jpeg
# Warning: No annotation found for image_24.jpeg
# Warning: No annotation found for image_2090.jpeg
# Warning: No annotation found for image_2839.jpeg
# Warning: No annotation found for image_1716.jpeg
# Warning: No annotation found for image_395.jpeg
# Warning: No annotation found for image_1346.jpeg
# Warning: No annotation found for image_2993.jpeg
# Warning: No annotation found for image_680.jpeg
# Warning: No annotation found for image_1653.jpeg
# Warning: No annotation found for image_1203.jpeg
# Warning: No annotation found for image_2585.jpeg
# Warning: No annotation found for image_403.jpeg
# Warning: No annotation found for image_1080.jpeg
# Warning: No annotation found for image_2706.jpeg
# Warning: No annotation found for image_1829.jpeg
# Warning: No annotation found for image_950.jpeg
# Warning: No annotation found for image_1983.jpeg
# Warning: No annotation found for image_2356.jpeg
# Warning: No annotation found for image_2643.jpeg
# Warning: No annotation found for image_2213.jpeg
# Warning: No annotation found for image_815.jpeg
# Warning: No annotation found for image_546.jpeg
# Warning: No annotation found for image_1595.jpeg
# Warning: No annotation found for image_116.jpeg
# Warning: No annotation found for image_638.jpeg
# Warning: No annotation found for image_1311.jpeg
# Warning: No annotation found for image_268.jpeg
# Warning: No annotation found for image_792.jpeg
# Warning: No annotation found for image_1741.jpeg
# Warning: No annotation found for image_2497.jpeg
# Warning: No annotation found for image_73.jpeg
# Warning: No annotation found for image_2478.jpeg
# Warning: No annotation found for image_2182.jpeg
# Warning: No annotation found for image_2028.jpeg
# Warning: No annotation found for image_287.jpeg
# Warning: No annotation found for image_1254.jpeg
# Warning: No annotation found for image_2881.jpeg
# Warning: No annotation found for image_1604.jpeg
# Warning: No annotation found for image_2301.jpeg
# Warning: No annotation found for image_907.jpeg
# Warning: No annotation found for image_2751.jpeg
# Warning: No annotation found for image_454.jpeg
# Warning: No annotation found for image_1487.jpeg
# Warning: No annotation found for image_141.jpeg
# Warning: No annotation found for image_1192.jpeg
# Warning: No annotation found for image_1468.jpeg
# Warning: No annotation found for image_511.jpeg
# Warning: No annotation found for image_1038.jpeg
# Warning: No annotation found for image_842.jpeg
# Warning: No annotation found for image_1891.jpeg
# Warning: No annotation found for image_2244.jpeg
# Warning: No annotation found for image_2614.jpeg
# Warning: No annotation found for image_2481.jpeg
# Warning: No annotation found for image_65.jpeg
# Warning: No annotation found for image_1757.jpeg
# Warning: No annotation found for image_2878.jpeg
# Warning: No annotation found for image_784.jpeg
# Warning: No annotation found for image_1307.jpeg
# Warning: No annotation found for image_1612.jpeg
# Warning: No annotation found for image_2897.jpeg
# Warning: No annotation found for image_1242.jpeg
# Warning: No annotation found for image_291.jpeg
# Warning: No annotation found for image_2194.jpeg
# Warning: No annotation found for image_1491.jpeg
# Warning: No annotation found for image_442.jpeg
# Warning: No annotation found for image_1868.jpeg
# Warning: No annotation found for image_2747.jpeg
# Warning: No annotation found for image_911.jpeg
# Warning: No annotation found for image_2317.jpeg
# Warning: No annotation found for image_2602.jpeg
# Warning: No annotation found for image_2252.jpeg
# Warning: No annotation found for image_1887.jpeg
# Warning: No annotation found for image_854.jpeg
# Warning: No annotation found for image_507.jpeg
# Warning: No annotation found for image_1184.jpeg
# Warning: No annotation found for image_157.jpeg
# Warning: No annotation found for image_679.jpeg
# Warning: No annotation found for image_2985.jpeg
# Warning: No annotation found for image_1350.jpeg
# Warning: No annotation found for image_383.jpeg
# Warning: No annotation found for image_229.jpeg
# Warning: No annotation found for image_1700.jpeg
# Warning: No annotation found for image_2086.jpeg
# Warning: No annotation found for image_32.jpeg
# Warning: No annotation found for image_2439.jpeg
# Warning: No annotation found for image_2069.jpeg
# Warning: No annotation found for image_2593.jpeg
# Warning: No annotation found for image_1215.jpeg
# Warning: No annotation found for image_1645.jpeg
# Warning: No annotation found for image_696.jpeg
# Warning: No annotation found for image_2340.jpeg
# Warning: No annotation found for image_1995.jpeg
# Warning: No annotation found for image_946.jpeg
# Warning: No annotation found for image_2710.jpeg
# Warning: No annotation found for image_1096.jpeg
# Warning: No annotation found for image_415.jpeg
# Warning: No annotation found for image_100.jpeg
# Warning: No annotation found for image_1429.jpeg
# Warning: No annotation found for image_1583.jpeg
# Warning: No annotation found for image_550.jpeg
# Warning: No annotation found for image_1079.jpeg
# Warning: No annotation found for image_803.jpeg
# Warning: No annotation found for image_2205.jpeg
# Warning: No annotation found for image_2655.jpeg
# Warning: No annotation found for image_222.jpeg
# Warning: No annotation found for image_2824.jpeg
# Warning: No annotation found for image_672.jpeg
# Warning: No annotation found for image_388.jpeg
# Warning: No annotation found for image_39.jpeg
# Warning: No annotation found for image_2127.jpeg
# Warning: No annotation found for image_2577.jpeg
# Warning: No annotation found for image_2062.jpeg
# Warning: No annotation found for image_2598.jpeg
# Warning: No annotation found for image_2432.jpeg
# Warning: No annotation found for image_2961.jpeg
# Warning: No annotation found for image_367.jpeg
# Warning: No annotation found for image_737.jpeg
# Warning: No annotation found for image_1834.jpeg
# Warning: No annotation found for image_1137.jpeg
# Warning: No annotation found for image_1567.jpeg
# Warning: No annotation found for image_1588.jpeg
# Warning: No annotation found for image_1072.jpeg
# Warning: No annotation found for image_1422.jpeg
# Warning: No annotation found for image_1971.jpeg
# Warning: No annotation found for image_808.jpeg
# Warning: No annotation found for image_2520.jpeg
# Warning: No annotation found for image_2170.jpeg
# Warning: No annotation found for image_625.jpeg
# Warning: No annotation found for image_2873.jpeg
# Warning: No annotation found for image_275.jpeg
# Warning: No annotation found for image_760.jpeg
# Warning: No annotation found for image_1249.jpeg
# Warning: No annotation found for image_330.jpeg
# Warning: No annotation found for image_1619.jpeg
# Warning: No annotation found for image_2936.jpeg
# Warning: No annotation found for image_81.jpeg
# Warning: No annotation found for image_2465.jpeg
# Warning: No annotation found for image_2035.jpeg
# Warning: No annotation found for image_1530.jpeg
# Warning: No annotation found for image_449.jpeg
# Warning: No annotation found for image_1160.jpeg
# Warning: No annotation found for image_1863.jpeg
# Warning: No annotation found for image_2259.jpeg
# Warning: No annotation found for image_1926.jpeg
# Warning: No annotation found for image_2609.jpeg
# Warning: No annotation found for image_1475.jpeg
# Warning: No annotation found for image_1025.jpeg
# Warning: No annotation found for image_263.jpeg
# Warning: No annotation found for image_799.jpeg
# Warning: No annotation found for image_2865.jpeg
# Warning: No annotation found for image_633.jpeg
# Warning: No annotation found for image_78.jpeg
# Warning: No annotation found for image_2166.jpeg
# Warning: No annotation found for image_2536.jpeg
# Warning: No annotation found for image_2023.jpeg
# Warning: No annotation found for image_97.jpeg
# Warning: No annotation found for image_2473.jpeg
# Warning: No annotation found for image_2189.jpeg
# Warning: No annotation found for image_2920.jpeg
# Warning: No annotation found for image_326.jpeg
# Warning: No annotation found for image_776.jpeg
# Warning: No annotation found for image_1875.jpeg
# Warning: No annotation found for image_1176.jpeg
# Warning: No annotation found for image_1526.jpeg
# Warning: No annotation found for image_1033.jpeg
# Warning: No annotation found for image_1199.jpeg
# Warning: No annotation found for image_1463.jpeg
# Warning: No annotation found for image_1930.jpeg
# Warning: No annotation found for image_849.jpeg
# Warning: No annotation found for image_2561.jpeg
# Warning: No annotation found for image_2131.jpeg
# Warning: No annotation found for image_2998.jpeg
# Warning: No annotation found for image_664.jpeg
# Warning: No annotation found for image_2832.jpeg
# Warning: No annotation found for image_234.jpeg
# Warning: No annotation found for image_721.jpeg
# Warning: No annotation found for image_1208.jpeg
# Warning: No annotation found for image_371.jpeg
# Warning: No annotation found for image_2977.jpeg
# Warning: No annotation found for image_1658.jpeg
# Warning: No annotation found for image_2424.jpeg
# Warning: No annotation found for image_2074.jpeg
# Warning: No annotation found for image_1571.jpeg
# Warning: No annotation found for image_408.jpeg
# Warning: No annotation found for image_1121.jpeg
# Warning: No annotation found for image_1988.jpeg
# Warning: No annotation found for image_1822.jpeg
# Warning: No annotation found for image_2218.jpeg
# Warning: No annotation found for image_2648.jpeg
# Warning: No annotation found for image_1967.jpeg
# Warning: No annotation found for image_1434.jpeg
# Warning: No annotation found for image_1064.jpeg
# Warning: No annotation found for image_1789.jpeg
# Warning: No annotation found for image_1273.jpeg
# Warning: No annotation found for image_1623.jpeg
# Warning: No annotation found for image_54.jpeg
# Warning: No annotation found for image_1336.jpeg
# Warning: No annotation found for image_2849.jpeg
# Warning: No annotation found for image_1766.jpeg
# Warning: No annotation found for image_2263.jpeg
# Warning: No annotation found for image_2799.jpeg
# Warning: No annotation found for image_865.jpeg
# Warning: No annotation found for image_2633.jpeg
# Warning: No annotation found for image_166.jpeg
# Warning: No annotation found for image_536.jpeg
# Warning: No annotation found for image_473.jpeg
# Warning: No annotation found for image_189.jpeg
# Warning: No annotation found for image_920.jpeg
# Warning: No annotation found for image_2326.jpeg
# Warning: No annotation found for image_2776.jpeg
# Warning: No annotation found for image_1859.jpeg
# Warning: No annotation found for image_2058.jpeg
# Warning: No annotation found for image_2408.jpeg
# Warning: No annotation found for image_1674.jpeg
# Warning: No annotation found for image_1224.jpeg
# Warning: No annotation found for image_218.jpeg
# Warning: No annotation found for image_1731.jpeg
# Warning: No annotation found for image_648.jpeg
# Warning: No annotation found for image_1361.jpeg
# Warning: No annotation found for image_561.jpeg
# Warning: No annotation found for image_1048.jpeg
# Warning: No annotation found for image_131.jpeg
# Warning: No annotation found for image_1418.jpeg
# Warning: No annotation found for image_998.jpeg
# Warning: No annotation found for image_2664.jpeg
# Warning: No annotation found for image_832.jpeg
# Warning: No annotation found for image_2234.jpeg
# Warning: No annotation found for image_2721.jpeg
# Warning: No annotation found for image_2371.jpeg
# Warning: No annotation found for image_977.jpeg
# Warning: No annotation found for image_424.jpeg
# Warning: No annotation found for image_1232.jpeg
# Warning: No annotation found for image_1398.jpeg
# Warning: No annotation found for image_1662.jpeg
# Warning: No annotation found for image_15.jpeg
# Warning: No annotation found for image_1377.jpeg
# Warning: No annotation found for image_1727.jpeg
# Warning: No annotation found for image_2808.jpeg
# Warning: No annotation found for image_2222.jpeg
# Warning: No annotation found for image_824.jpeg
# Warning: No annotation found for image_2672.jpeg
# Warning: No annotation found for image_2388.jpeg
# Warning: No annotation found for image_127.jpeg
# Warning: No annotation found for image_577.jpeg
# Warning: No annotation found for image_598.jpeg
# Warning: No annotation found for image_432.jpeg
# Warning: No annotation found for image_961.jpeg
# Warning: No annotation found for image_2367.jpeg
# Warning: No annotation found for image_1818.jpeg
# Warning: No annotation found for image_2737.jpeg
# Warning: No annotation found for image_2019.jpeg
# Warning: No annotation found for image_2449.jpeg
# Warning: No annotation found for image_1635.jpeg
# Warning: No annotation found for image_1265.jpeg
# Warning: No annotation found for image_259.jpeg
# Warning: No annotation found for image_1770.jpeg
# Warning: No annotation found for image_609.jpeg
# Warning: No annotation found for image_1320.jpeg
# Warning: No annotation found for image_42.jpeg
# Warning: No annotation found for image_520.jpeg
# Warning: No annotation found for image_1009.jpeg
# Warning: No annotation found for image_170.jpeg
# Warning: No annotation found for image_1459.jpeg
# Warning: No annotation found for image_2625.jpeg
# Warning: No annotation found for image_873.jpeg
# Warning: No annotation found for image_2275.jpeg
# Warning: No annotation found for image_2760.jpeg
# Warning: No annotation found for image_2330.jpeg
# Warning: No annotation found for image_936.jpeg
# Warning: No annotation found for image_465.jpeg
# Warning: No annotation found for image_1091.jpeg
# Warning: No annotation found for image_412.jpeg
# Warning: No annotation found for image_941.jpeg
# Warning: No annotation found for image_1992.jpeg
# Warning: No annotation found for image_2347.jpeg
# Warning: No annotation found for image_1838.jpeg
# Warning: No annotation found for image_2717.jpeg
# Warning: No annotation found for image_2202.jpeg
# Warning: No annotation found for image_804.jpeg
# Warning: No annotation found for image_2652.jpeg
# Warning: No annotation found for image_107.jpeg
# Warning: No annotation found for image_557.jpeg
# Warning: No annotation found for image_1584.jpeg
# Warning: No annotation found for image_2081.jpeg
# Warning: No annotation found for image_35.jpeg
# Warning: No annotation found for image_384.jpeg
# Warning: No annotation found for image_1357.jpeg
# Warning: No annotation found for image_2982.jpeg
# Warning: No annotation found for image_1707.jpeg
# Warning: No annotation found for image_2828.jpeg
# Warning: No annotation found for image_1212.jpeg
# Warning: No annotation found for image_691.jpeg
# Warning: No annotation found for image_1642.jpeg
# Warning: No annotation found for image_2594.jpeg
# Warning: No annotation found for image_2740.jpeg
# Warning: No annotation found for image_2310.jpeg
# Warning: No annotation found for image_916.jpeg
# Warning: No annotation found for image_445.jpeg
# Warning: No annotation found for image_1496.jpeg
# Warning: No annotation found for image_500.jpeg
# Warning: No annotation found for image_1029.jpeg
# Warning: No annotation found for image_150.jpeg
# Warning: No annotation found for image_1183.jpeg
# Warning: No annotation found for image_1479.jpeg
# Warning: No annotation found for image_2605.jpeg
# Warning: No annotation found for image_853.jpeg
# Warning: No annotation found for image_1880.jpeg
# Warning: No annotation found for image_2255.jpeg
# Warning: No annotation found for image_279.jpeg
# Warning: No annotation found for image_783.jpeg
# Warning: No annotation found for image_1750.jpeg
# Warning: No annotation found for image_629.jpeg
# Warning: No annotation found for image_1300.jpeg
# Warning: No annotation found for image_62.jpeg
# Warning: No annotation found for image_2486.jpeg
# Warning: No annotation found for image_2039.jpeg
# Warning: No annotation found for image_2469.jpeg
# Warning: No annotation found for image_2193.jpeg
# Warning: No annotation found for image_1615.jpeg
# Warning: No annotation found for image_296.jpeg
# Warning: No annotation found for image_1245.jpeg
# Warning: No annotation found for image_2890.jpeg
# Warning: No annotation found for image_1480.jpeg
# Warning: No annotation found for image_453.jpeg
# Warning: No annotation found for image_900.jpeg
# Warning: No annotation found for image_2306.jpeg
# Warning: No annotation found for image_2756.jpeg
# Warning: No annotation found for image_1879.jpeg
# Warning: No annotation found for image_2243.jpeg
# Warning: No annotation found for image_1896.jpeg
# Warning: No annotation found for image_845.jpeg
# Warning: No annotation found for image_2613.jpeg
# Warning: No annotation found for image_1195.jpeg
# Warning: No annotation found for image_146.jpeg
# Warning: No annotation found for image_516.jpeg
# Warning: No annotation found for image_74.jpeg
# Warning: No annotation found for image_2490.jpeg
# Warning: No annotation found for image_1316.jpeg
# Warning: No annotation found for image_2869.jpeg
# Warning: No annotation found for image_1746.jpeg
# Warning: No annotation found for image_795.jpeg
# Warning: No annotation found for image_2886.jpeg
# Warning: No annotation found for image_1253.jpeg
# ...
# Warning: No annotation found for image_118.jpeg
# Warning: No annotation found for image_1431.jpeg
# Warning: No annotation found for image_548.jpeg
# Warning: No annotation found for image_1061.jpeg
# Warning: No annotation found for image_1574.jpeg
# Warning: No annotation found for image_1124.jpeg
# Warning: No annotation found for image_2358.jpeg
# Warning: No annotation found for image_1827.jpeg
# Warning: No annotation found for image_2708.jpeg
# Warning: No annotation found for image_51.jpeg
# Warning: No annotation found for image_1333.jpeg
# Warning: No annotation found for image_1299.jpeg
# Warning: No annotation found for image_1763.jpeg
# Warning: No annotation found for image_1276.jpeg
# Warning: No annotation found for image_1626.jpeg
# Warning: No annotation found for image_2909.jpeg
# Warning: No annotation found for image_476.jpeg
# Warning: No annotation found for image_2323.jpeg
# Warning: No annotation found for image_925.jpeg
# Warning: No annotation found for image_2773.jpeg
# Warning: No annotation found for image_2289.jpeg
# Warning: No annotation found for image_860.jpeg
# Warning: No annotation found for image_2266.jpeg
# Warning: No annotation found for image_1919.jpeg
# Warning: No annotation found for image_2636.jpeg
# Warning: No annotation found for image_163.jpeg
# Warning: No annotation found for image_499.jpeg
# Warning: No annotation found for image_533.jpeg
# Warning: No annotation found for image_1734.jpeg
# Warning: No annotation found for image_1364.jpeg
# Warning: No annotation found for image_2118.jpeg
# Warning: No annotation found for image_2548.jpeg
# Warning: No annotation found for image_358.jpeg
# Warning: No annotation found for image_1671.jpeg
# Warning: No annotation found for image_708.jpeg
# Warning: No annotation found for image_1221.jpeg
# Warning: No annotation found for image_2724.jpeg
# Warning: No annotation found for image_972.jpeg
# Warning: No annotation found for image_2374.jpeg
# Warning: No annotation found for image_421.jpeg
# Warning: No annotation found for image_1108.jpeg
# Warning: No annotation found for image_1558.jpeg
# Warning: No annotation found for image_564.jpeg
# Warning: No annotation found for image_134.jpeg
# Warning: No annotation found for image_2661.jpeg
# Warning: No annotation found for image_2231.jpeg
# Warning: No annotation found for image_837.jpeg
# Warning: No annotation found for image_10.jpeg
# Warning: No annotation found for image_1688.jpeg
# Warning: No annotation found for image_1372.jpeg
# Warning: No annotation found for image_1722.jpeg
# Warning: No annotation found for image_1237.jpeg
# Warning: No annotation found for image_2948.jpeg
# Warning: No annotation found for image_1667.jpeg
# Warning: No annotation found for image_437.jpeg
# Warning: No annotation found for image_2362.jpeg
# Warning: No annotation found for image_964.jpeg
# Warning: No annotation found for image_2698.jpeg
# Warning: No annotation found for image_2732.jpeg
# Warning: No annotation found for image_821.jpeg
# Warning: No annotation found for image_2227.jpeg
# Warning: No annotation found for image_2677.jpeg
# Warning: No annotation found for image_1958.jpeg
# Warning: No annotation found for image_122.jpeg
# Warning: No annotation found for image_572.jpeg
# Warning: No annotation found for image_1775.jpeg
# Warning: No annotation found for image_1325.jpeg
# Warning: No annotation found for image_2159.jpeg
# Warning: No annotation found for image_47.jpeg
# Warning: No annotation found for image_2509.jpeg
# Warning: No annotation found for image_319.jpeg
# Warning: No annotation found for image_1630.jpeg
# Warning: No annotation found for image_749.jpeg
# Warning: No annotation found for image_1260.jpeg
# Warning: No annotation found for image_2765.jpeg
# Warning: No annotation found for image_899.jpeg
# Warning: No annotation found for image_933.jpeg
# Warning: No annotation found for image_2335.jpeg
# Warning: No annotation found for image_460.jpeg
# Warning: No annotation found for image_1149.jpeg
# Warning: No annotation found for image_1519.jpeg
# Warning: No annotation found for image_525.jpeg
# Warning: No annotation found for image_175.jpeg
# Warning: No annotation found for image_2620.jpeg
# Warning: No annotation found for image_2270.jpeg
# Warning: No annotation found for image_876.jpeg
# Warning: No annotation found for image_801.jpeg
# Warning: No annotation found for image_2207.jpeg
# Warning: No annotation found for image_2657.jpeg
# Warning: No annotation found for image_1978.jpeg
# Warning: No annotation found for image_102.jpeg
# Warning: No annotation found for image_552.jpeg
# Warning: No annotation found for image_1581.jpeg
# Warning: No annotation found for image_1094.jpeg
# Warning: No annotation found for image_417.jpeg
# Warning: No annotation found for image_2342.jpeg
# Warning: No annotation found for image_944.jpeg
# Warning: No annotation found for image_1997.jpeg
# Warning: No annotation found for image_2712.jpeg
# Warning: No annotation found for image_1217.jpeg
# Warning: No annotation found for image_694.jpeg
# Warning: No annotation found for image_2968.jpeg
# Warning: No annotation found for image_1647.jpeg
# Warning: No annotation found for image_9.jpeg
# Warning: No annotation found for image_2591.jpeg
# Warning: No annotation found for image_2084.jpeg
# Warning: No annotation found for image_30.jpeg
# Warning: No annotation found for image_2987.jpeg
# Warning: No annotation found for image_381.jpeg
# Warning: No annotation found for image_1352.jpeg
# Warning: No annotation found for image_1702.jpeg
# Warning: No annotation found for image_505.jpeg
# Warning: No annotation found for image_155.jpeg
# Warning: No annotation found for image_1186.jpeg
# Warning: No annotation found for image_2600.jpeg
# Warning: No annotation found for image_2250.jpeg
# Warning: No annotation found for image_856.jpeg
# Warning: No annotation found for image_1885.jpeg
# Warning: No annotation found for image_2745.jpeg
# Warning: No annotation found for image_913.jpeg
# Warning: No annotation found for image_2315.jpeg
# Warning: No annotation found for image_440.jpeg
# Warning: No annotation found for image_1493.jpeg
# Warning: No annotation found for image_1169.jpeg
# Warning: No annotation found for image_1539.jpeg
# Warning: No annotation found for image_2196.jpeg
# Warning: No annotation found for image_88.jpeg
# Warning: No annotation found for image_339.jpeg
# Warning: No annotation found for image_1610.jpeg
# Warning: No annotation found for image_2895.jpeg
# Warning: No annotation found for image_769.jpeg
# Warning: No annotation found for image_293.jpeg
# Warning: No annotation found for image_1240.jpeg
# Warning: No annotation found for image_786.jpeg
# Warning: No annotation found for image_1755.jpeg
# Warning: No annotation found for image_1305.jpeg
# Warning: No annotation found for image_2179.jpeg
# Warning: No annotation found for image_67.jpeg
# Warning: No annotation found for image_2483.jpeg
# Warning: No annotation found for image_2529.jpeg
# Warning: No annotation found for image_1893.jpeg
# Warning: No annotation found for image_840.jpeg
# Warning: No annotation found for image_2246.jpeg
# Warning: No annotation found for image_1939.jpeg
# Warning: No annotation found for image_2616.jpeg
# Warning: No annotation found for image_1190.jpeg
# Warning: No annotation found for image_143.jpeg
# Warning: No annotation found for image_513.jpeg
# Warning: No annotation found for image_1485.jpeg
# Warning: No annotation found for image_456.jpeg
# Warning: No annotation found for image_2303.jpeg
# Warning: No annotation found for image_905.jpeg
# Warning: No annotation found for image_2753.jpeg
# Warning: No annotation found for image_1256.jpeg
# Warning: No annotation found for image_285.jpeg
# Warning: No annotation found for image_2883.jpeg
# Warning: No annotation found for image_1606.jpeg
# Warning: No annotation found for image_2929.jpeg
# Warning: No annotation found for image_2180.jpeg
# Warning: No annotation found for image_71.jpeg
# Warning: No annotation found for image_2495.jpeg
# Warning: No annotation found for image_1313.jpeg
# Warning: No annotation found for image_1743.jpeg
# Warning: No annotation found for image_790.jpeg
# Warning: No annotation found for image_1597.jpeg
# Warning: No annotation found for image_544.jpeg
# Warning: No annotation found for image_114.jpeg
# Warning: No annotation found for image_2641.jpeg
# Warning: No annotation found for image_2211.jpeg
# Warning: No annotation found for image_817.jpeg
# Warning: No annotation found for image_2704.jpeg
# Warning: No annotation found for image_1981.jpeg
# Warning: No annotation found for image_952.jpeg
# Warning: No annotation found for image_2354.jpeg
# Warning: No annotation found for image_401.jpeg
# Warning: No annotation found for image_1128.jpeg
# Warning: No annotation found for image_1082.jpeg
# Warning: No annotation found for image_1578.jpeg
# Warning: No annotation found for image_2587.jpeg
# Warning: No annotation found for image_378.jpeg
# Warning: No annotation found for image_1651.jpeg
# Warning: No annotation found for image_682.jpeg
# Warning: No annotation found for image_728.jpeg
# Warning: No annotation found for image_1201.jpeg
# Warning: No annotation found for image_1714.jpeg
# Warning: No annotation found for image_1344.jpeg
# Warning: No annotation found for image_397.jpeg
# Warning: No annotation found for image_2991.jpeg
# Warning: No annotation found for image_2138.jpeg
# Warning: No annotation found for image_26.jpeg
# Warning: No annotation found for image_2568.jpeg
# Warning: No annotation found for image_2092.jpeg
# Warning: No annotation found for image_2285.jpeg
# Warning: No annotation found for image_1850.jpeg
# Warning: No annotation found for image_883.jpeg
# Warning: No annotation found for image_929.jpeg
# Warning: No annotation found for image_1153.jpeg
# Warning: No annotation found for image_180.jpeg
# Warning: No annotation found for image_1503.jpeg
# Warning: No annotation found for image_1016.jpeg
# Warning: No annotation found for image_1446.jpeg
# Warning: No annotation found for image_495.jpeg
# Warning: No annotation found for image_1915.jpeg
# Warning: No annotation found for image_2790.jpeg
# Warning: No annotation found for image_2840.jpeg
# Warning: No annotation found for image_1295.jpeg
# Warning: No annotation found for image_246.jpeg
# Warning: No annotation found for image_616.jpeg
# Warning: No annotation found for image_2143.jpeg
# Warning: No annotation found for image_2513.jpeg
# Warning: No annotation found for image_2006.jpeg
# Warning: No annotation found for image_2456.jpeg
# Warning: No annotation found for image_303.jpeg
# Warning: No annotation found for image_2905.jpeg
# Warning: No annotation found for image_1780.jpeg
# Warning: No annotation found for image_753.jpeg
# Warning: No annotation found for image_1554.jpeg
# Warning: No annotation found for image_587.jpeg
# Warning: No annotation found for image_1104.jpeg
# Warning: No annotation found for image_2378.jpeg
# Warning: No annotation found for image_2682.jpeg
# Warning: No annotation found for image_1807.jpeg
# Warning: No annotation found for image_2728.jpeg
# Warning: No annotation found for image_2397.jpeg
# Warning: No annotation found for image_1942.jpeg
# Warning: No annotation found for image_991.jpeg
# Warning: No annotation found for image_138.jpeg
# Warning: No annotation found for image_1411.jpeg
# Warning: No annotation found for image_568.jpeg
# Warning: No annotation found for image_1041.jpeg
# Warning: No annotation found for image_2544.jpeg
# Warning: No annotation found for image_2114.jpeg
# Warning: No annotation found for image_1692.jpeg
# Warning: No annotation found for image_641.jpeg
# Warning: No annotation found for image_1368.jpeg
# Warning: No annotation found for image_211.jpeg
# Warning: No annotation found for image_1738.jpeg
# Warning: No annotation found for image_2817.jpeg
# Warning: No annotation found for image_704.jpeg
# Warning: No annotation found for image_2952.jpeg
# Warning: No annotation found for image_1387.jpeg
# Warning: No annotation found for image_354.jpeg
# Warning: No annotation found for image_2401.jpeg
# Warning: No annotation found for image_2051.jpeg
# Warning: No annotation found for image_1811.jpeg
# Warning: No annotation found for image_2694.jpeg
# Warning: No annotation found for image_968.jpeg
# Warning: No annotation found for image_1112.jpeg
# Warning: No annotation found for image_591.jpeg
# Warning: No annotation found for image_1542.jpeg
# Warning: No annotation found for image_1057.jpeg
# Warning: No annotation found for image_1407.jpeg
# Warning: No annotation found for image_987.jpeg
# Warning: No annotation found for image_1954.jpeg
# Warning: No annotation found for image_2381.jpeg
# Warning: No annotation found for image_2801.jpeg
# Warning: No annotation found for image_207.jpeg
# Warning: No annotation found for image_657.jpeg
# Warning: No annotation found for image_1684.jpeg
# Warning: No annotation found for image_2102.jpeg
# Warning: No annotation found for image_2552.jpeg
# Warning: No annotation found for image_2047.jpeg
# Warning: No annotation found for image_2417.jpeg
# Warning: No annotation found for image_342.jpeg
# Warning: No annotation found for image_1391.jpeg
# Warning: No annotation found for image_2944.jpeg
# Warning: No annotation found for image_712.jpeg
# Warning: No annotation found for image_1515.jpeg
# Warning: No annotation found for image_196.jpeg
# Warning: No annotation found for image_1145.jpeg
# Warning: No annotation found for image_2339.jpeg
# Warning: No annotation found for image_895.jpeg
# Warning: No annotation found for image_2769.jpeg
# Warning: No annotation found for image_1846.jpeg
# Warning: No annotation found for image_2293.jpeg
# Warning: No annotation found for image_2786.jpeg
# Warning: No annotation found for image_1903.jpeg
# Warning: No annotation found for image_179.jpeg
# Warning: No annotation found for image_483.jpeg
# Warning: No annotation found for image_1450.jpeg
# Warning: No annotation found for image_529.jpeg
# Warning: No annotation found for image_1000.jpeg
# Warning: No annotation found for image_2505.jpeg
# Warning: No annotation found for image_2155.jpeg
# Warning: No annotation found for image_600.jpeg
# Warning: No annotation found for image_1329.jpeg
# Warning: No annotation found for image_250.jpeg
# Warning: No annotation found for image_1283.jpeg
# Warning: No annotation found for image_2856.jpeg
# Warning: No annotation found for image_1779.jpeg
# Warning: No annotation found for image_745.jpeg
# Warning: No annotation found for image_1796.jpeg
# Warning: No annotation found for image_2913.jpeg
# Warning: No annotation found for image_315.jpeg
# Warning: No annotation found for image_2440.jpeg
# Warning: No annotation found for image_2010.jpeg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 60
#      58 from torch.utils.data import DataLoader
#      59 dataset = load_dataset(image_paths, annotations)
# ---> 60 dataloader = DataLoader(dataset, batch_size=4, shuffle=True, collate_fn=lambda x: tuple(zip(*x)))
#      62 print(f"Loaded {len(dataset)} images with annotations.")
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/torch/utils/data/dataloader.py:350, in DataLoader.__init__(self, dataset, batch_size, shuffle, sampler, batch_sampler, num_workers, collate_fn, pin_memory, drop_last, timeout, worker_init_fn, multiprocessing_context, generator, prefetch_factor, persistent_workers, pin_memory_device)
#     348 else:  # map-style
#     349     if shuffle:
# --> 350         sampler = RandomSampler(dataset, generator=generator)  # type: ignore[arg-type]
#     351     else:
#     352         sampler = SequentialSampler(dataset)  # type: ignore[arg-type]
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/torch/utils/data/sampler.py:143, in RandomSampler.__init__(self, data_source, replacement, num_samples, generator)
#     140     raise TypeError(f"replacement should be a boolean value, but got replacement={self.replacement}")
#     142 if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# --> 143     raise ValueError(f"num_samples should be a positive integer value, but got num_samples={self.num_samples}")
#
# ValueError: num_samples should be a positive integer value, but got num_samples=0

# %%
import os
import random
import torch
from PIL import Image
import torchvision.transforms as T
import json
import torchvision
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torch.utils.data import DataLoader

# Set random seed for reproducibility
random.seed(42)
torch.manual_seed(42)

# Define the path to your furniture folder
downloads_path = os.path.expanduser("~/Downloads/furniture")  # Adjust for Windows: r"C:\Users\<YourUsername>\Downloads\furniture"

# Get list of image paths from all subfolders
image_paths = []
subfolders = ["cabinets,cupboards,etc", "chair", "fridge", "table", "tv"]
for subfolder in subfolders:
    subfolder_path = os.path.join(downloads_path, subfolder)
    for fname in os.listdir(subfolder_path):
        if fname.lower().endswith((".jpg", ".png", ".jpeg", ".jpe")):
            image_paths.append(os.path.join(subfolder_path, fname))

# Select one random image from each subfolder (total 5 images)
selected_image_paths = []
for subfolder in subfolders:
    subfolder_path = os.path.join(downloads_path, subfolder)
    subfolder_images = [p for p in image_paths if subfolder in p]
    if subfolder_images:
        selected_image_paths.append(random.choice(subfolder_images))

# Debugging: Print selected image paths
print("Selected image paths:")
for img_path in selected_image_paths:
    print(img_path)

# Create dummy annotations
# Categories: 1=cabinets, 2=chair, 3=fridge, 4=table, 5=tv
categories = [
    {"id": 1, "name": "cabinets"},
    {"id": 2, "name": "chair"},
    {"id": 3, "name": "fridge"},
    {"id": 4, "name": "table"},
    {"id": 5, "name": "tv"}
]

# Generate dummy COCO-format annotations
coco_data = {
    "images": [],
    "annotations": [],
    "categories": categories
}

for idx, img_path in enumerate(selected_image_paths):
    # Get image dimensions
    img = Image.open(img_path).convert("RGB")
    width, height = img.size
    
    # Add image metadata
    relative_path = os.path.join(os.path.basename(os.path.dirname(img_path)), os.path.basename(img_path))
    # Normalize the path separator and extension
    relative_path = relative_path.replace(os.sep, "/").lower().replace(".jpe", ".jpeg")
    coco_data["images"].append({
        "id": idx + 1,
        "file_name": relative_path,
        "width": width,
        "height": height
    })
    
    # Add a dummy bounding box (e.g., center of the image, 100x100 pixels)
    box = [width/2 - 50, height/2 - 50, 100, 100]  # [x, y, width, height]
    category_id = subfolders.index(os.path.basename(os.path.dirname(img_path))) + 1
    coco_data["annotations"].append({
        "image_id": idx + 1,
        "bbox": box,
        "category_id": category_id,
        "id": idx + 1
    })

# Debugging: Print the file names in coco_data
print("\nFile names in coco_data['images']:")
for item in coco_data["images"]:
    print(item["file_name"])

# Map annotations to images
annotations = []
for img_path in selected_image_paths:
    relative_path = os.path.join(os.path.basename(os.path.dirname(img_path)), os.path.basename(img_path))
    relative_path = relative_path.replace(os.sep, "/").lower().replace(".jpe", ".jpeg")
    print(f"\nTrying to match: {relative_path}")
    
    img_id = next((item["id"] for item in coco_data["images"] if item["file_name"].lower() == relative_path), None)
    if img_id is None:
        print(f"Warning: No match found for {relative_path}")
        continue
    img_annotations = [ann for ann in coco_data["annotations"] if ann["image_id"] == img_id]
    boxes = [[ann["bbox"][0], ann["bbox"][1], ann["bbox"][0] + ann["bbox"][2], ann["bbox"][1] + ann["bbox"][3]] for ann in img_annotations]
    labels = [ann["category_id"] for ann in img_annotations]
    annotations.append({
        "boxes": boxes,
        "labels": labels
    })

# Filter image_paths to only include images with annotations
selected_image_paths = [img_path for img_path, ann in zip(selected_image_paths, annotations) if ann["boxes"] and ann["labels"]]

# Define the load_dataset function
def load_dataset(image_paths, annotations):
    dataset = []
    transform = T.ToTensor()
    for img_path, ann in zip(image_paths, annotations):
        img = Image.open(img_path).convert("RGB")
        img_tensor = transform(img)
        target = {
            "boxes": torch.tensor(ann["boxes"], dtype=torch.float32),
            "labels": torch.tensor(ann["labels"], dtype=torch.int64)
        }
        dataset.append((img_tensor, target))
    return dataset

# Create dataset and DataLoader
dataset = load_dataset(selected_image_paths, annotations)
dataloader = DataLoader(dataset, batch_size=2, shuffle=True, collate_fn=lambda x: tuple(zip(*x)))

# Load Faster R-CNN model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = fasterrcnn_resnet50_fpn(pretrained=True)
num_classes = 6  # 5 classes + background
in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = torchvision.models.detection.faster_rcnn.FastRCNNPredictor(in_features, num_classes)
model = model.to(device)

# Training setup
model.train()
optimizer = torch.optim.SGD(model.parameters(), lr=0.005, momentum=0.9, weight_decay=0.0005)
num_epochs = 5

# Training loop
for epoch in range(num_epochs):
    for images, targets in dataloader:
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())
        optimizer.zero_grad()
        losses.backward()
        optimizer.step()
    print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {losses.item()}")

print("Training completed.")
# Out:
# Selected image paths:
# /Users/skyzhao/Downloads/furniture/cabinets,cupboards,etc/image_226.jpeg
# /Users/skyzhao/Downloads/furniture/chair/image_1599.jpeg
# /Users/skyzhao/Downloads/furniture/fridge/image_1202.jpeg
# /Users/skyzhao/Downloads/furniture/table/image_1638.jpeg
# /Users/skyzhao/Downloads/furniture/tv/image_2214.jpeg
#
# File names in coco_data['images']:
# cabinets,cupboards,etc/image_226.jpegg
# chair/image_1599.jpegg
# fridge/image_1202.jpegg
# table/image_1638.jpegg
# tv/image_2214.jpegg
#
# Trying to match: cabinets,cupboards,etc/image_226.jpegg
#
# Trying to match: chair/image_1599.jpegg
#
# Trying to match: fridge/image_1202.jpegg
#
# Trying to match: table/image_1638.jpegg
#
# Trying to match: tv/image_2214.jpegg
# /Users/skyzhao/.pyenv/versions/3.12.7/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/skyzhao/.pyenv/versions/3.12.7/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/5, Loss: 0.4183807373046875
# Epoch 2/5, Loss: 0.6392212510108948
# Epoch 3/5, Loss: 0.44014203548431396
# Epoch 4/5, Loss: 0.29586315155029297
# Epoch 5/5, Loss: 0.3235889673233032
# Training completed.

# %%
import os
import random
import torch
from PIL import Image
import torchvision.transforms as T
import json
import torchvision
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torchvision.models.detection.faster_rcnn import FasterRCNN_ResNet50_FPN_Weights
from torch.utils.data import DataLoader

# Set random seed for reproducibility
random.seed(42)
torch.manual_seed(42)

# Define the path to your furniture folder
downloads_path = os.path.expanduser("~/Downloads/furniture")  # Adjust for Windows: r"C:\Users\<YourUsername>\Downloads\furniture"

# Get list of image paths from all subfolders
image_paths = []
subfolders = ["cabinets,cupboards,etc", "chair", "fridge", "table", "tv"]
for subfolder in subfolders:
    subfolder_path = os.path.join(downloads_path, subfolder)
    for fname in os.listdir(subfolder_path):
        if fname.lower().endswith((".jpg", ".png", ".jpeg", ".jpe")):
            image_paths.append(os.path.join(subfolder_path, fname))

# Select one random image from each subfolder (total 5 images)
selected_image_paths = []
for subfolder in subfolders:
    subfolder_path = os.path.join(downloads_path, subfolder)
    subfolder_images = [p for p in image_paths if subfolder in p]
    if subfolder_images:
        selected_image_paths.append(random.choice(subfolder_images))

# Debugging: Print selected image paths
print("Selected image paths:")
for img_path in selected_image_paths:
    print(img_path)

# Create dummy annotations
# Categories: 1=cabinets, 2=chair, 3=fridge, 4=table, 5=tv
categories = [
    {"id": 1, "name": "cabinets"},
    {"id": 2, "name": "chair"},
    {"id": 3, "name": "fridge"},
    {"id": 4, "name": "table"},
    {"id": 5, "name": "tv"}
]

# Generate dummy COCO-format annotations
coco_data = {
    "images": [],
    "annotations": [],
    "categories": categories
}

for idx, img_path in enumerate(selected_image_paths):
    # Get image dimensions
    img = Image.open(img_path).convert("RGB")
    width, height = img.size
    
    # Add image metadata
    relative_path = os.path.join(os.path.basename(os.path.dirname(img_path)), os.path.basename(img_path))
    # Normalize the path separator and extension
    relative_path = relative_path.replace(os.sep, "/").lower().replace(".jpe", ".jpeg")
    coco_data["images"].append({
        "id": idx + 1,
        "file_name": relative_path,
        "width": width,
        "height": height
    })
    
    # Add a dummy bounding box (e.g., center of the image, 100x100 pixels)
    box = [width/2 - 50, height/2 - 50, 100, 100]  # [x, y, width, height]
    category_id = subfolders.index(os.path.basename(os.path.dirname(img_path))) + 1
    coco_data["annotations"].append({
        "image_id": idx + 1,
        "bbox": box,
        "category_id": category_id,
        "id": idx + 1
    })

# Debugging: Print the file names in coco_data['images']
print("\nFile names in coco_data['images']:")
for item in coco_data["images"]:
    print(item["file_name"])

# Map annotations to images
annotations = []
for img_path in selected_image_paths:
    relative_path = os.path.join(os.path.basename(os.path.dirname(img_path)), os.path.basename(img_path))
    relative_path = relative_path.replace(os.sep, "/").lower().replace(".jpe", ".jpeg")
    print(f"\nTrying to match: {relative_path}")
    
    img_id = next((item["id"] for item in coco_data["images"] if item["file_name"].lower() == relative_path), None)
    if img_id is None:
        print(f"Warning: No match found for {relative_path}")
        continue
    img_annotations = [ann for ann in coco_data["annotations"] if ann["image_id"] == img_id]
    boxes = [[ann["bbox"][0], ann["bbox"][1], ann["bbox"][0] + ann["bbox"][2], ann["bbox"][1] + ann["bbox"][3]] for ann in img_annotations]
    labels = [ann["category_id"] for ann in img_annotations]
    annotations.append({
        "boxes": boxes,
        "labels": labels
    })

# Filter image_paths to only include images with annotations
selected_image_paths = [img_path for img_path, ann in zip(selected_image_paths, annotations) if ann["boxes"] and ann["labels"]]

# Define the load_dataset function
def load_dataset(image_paths, annotations):
    dataset = []
    transform = T.ToTensor()
    for img_path, ann in zip(image_paths, annotations):
        img = Image.open(img_path).convert("RGB")
        img_tensor = transform(img)
        target = {
            "boxes": torch.tensor(ann["boxes"], dtype=torch.float32),
            "labels": torch.tensor(ann["labels"], dtype=torch.int64)
        }
        dataset.append((img_tensor, target))
    return dataset

# Create dataset and DataLoader
dataset = load_dataset(selected_image_paths, annotations)
dataloader = DataLoader(dataset, batch_size=2, shuffle=True, collate_fn=lambda x: tuple(zip(*x)))

# Load Faster R-CNN model with updated weights parameter
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = fasterrcnn_resnet50_fpn(weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT)
num_classes = 6  # 5 classes + background
in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = torchvision.models.detection.faster_rcnn.FastRCNNPredictor(in_features, num_classes)
model = model.to(device)

# Training setup
model.train()
optimizer = torch.optim.SGD(model.parameters(), lr=0.005, momentum=0.9, weight_decay=0.0005)
num_epochs = 5

# Training loop
for epoch in range(num_epochs):
    for images, targets in dataloader:
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())
        optimizer.zero_grad()
        losses.backward()
        optimizer.step()
    print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {losses.item()}")

print("Training completed.")
# Out:
# Selected image paths:
# /Users/skyzhao/Downloads/furniture/cabinets,cupboards,etc/image_226.jpeg
# /Users/skyzhao/Downloads/furniture/chair/image_1599.jpeg
# /Users/skyzhao/Downloads/furniture/fridge/image_1202.jpeg
# /Users/skyzhao/Downloads/furniture/table/image_1638.jpeg
# /Users/skyzhao/Downloads/furniture/tv/image_2214.jpeg
#
# File names in coco_data['images']:
# cabinets,cupboards,etc/image_226.jpegg
# chair/image_1599.jpegg
# fridge/image_1202.jpegg
# table/image_1638.jpegg
# tv/image_2214.jpegg
#
# Trying to match: cabinets,cupboards,etc/image_226.jpegg
#
# Trying to match: chair/image_1599.jpegg
#
# Trying to match: fridge/image_1202.jpegg
#
# Trying to match: table/image_1638.jpegg
#
# Trying to match: tv/image_2214.jpegg
# Epoch 1/5, Loss: 0.4183807373046875
# Epoch 2/5, Loss: 0.6392212510108948
# Epoch 3/5, Loss: 0.44014203548431396
# Epoch 4/5, Loss: 0.29586315155029297
# Epoch 5/5, Loss: 0.3235889673233032
# Training completed.

# %%
from torchvision.models.detection.transform import GeneralizedRCNNTransform
from torchvision.ops import box_iou
import numpy as np

def evaluate(model, dataloader, device):
    model.eval()
    total_iou = 0
    total_predictions = 0

    with torch.no_grad():
        for images, targets in dataloader:
            images = list(img.to(device) for img in images)
            outputs = model(images)

            for pred, true in zip(outputs, targets):
                pred_boxes = pred['boxes'].cpu()
                true_boxes = true['boxes'].cpu()
                
                if len(pred_boxes) == 0 or len(true_boxes) == 0:
                    continue

                ious = box_iou(pred_boxes, true_boxes)  # shape: [pred, true]
                max_ious = ious.max(dim=1)[0]  # best match for each prediction
                total_iou += max_ious.sum().item()
                total_predictions += len(pred_boxes)

    mean_iou = total_iou / total_predictions if total_predictions > 0 else 0
    print(f"Mean IoU over predictions: {mean_iou:.4f}")
