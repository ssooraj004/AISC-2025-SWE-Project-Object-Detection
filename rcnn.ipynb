# %%
import os
import torch
from PIL import Image
import torchvision.transforms as T
import json

# Define the path to your furniture folder
downloads_path = os.path.expanduser("~/Downloads/furniture")  # Adjust for Windows: r"C:\Users\<YourUsername>\Downloads\furniture"

# Get list of image paths from all subfolders
image_paths = []
subfolders = ["cabinets,cupboards,etc", "chair", "fridge", "table", "tv"]
for subfolder in subfolders:
    subfolder_path = os.path.join(downloads_path, subfolder)
    for fname in os.listdir(subfolder_path):
        if fname.lower().endswith((".jpg", ".png", ".jpeg")):
            image_paths.append(os.path.join(subfolder_path, fname))

# Load annotations (assuming COCO JSON format)
annotations_path = os.path.join(downloads_path, "annotations.json")
with open(annotations_path, "r") as f:
    coco_data = json.load(f)

# Map annotations to images
annotations = []
for img_path in image_paths:
    img_name = os.path.basename(img_path)
    img_id = next((item["id"] for item in coco_data["images"] if item["file_name"] == img_name), None)
    if img_id is None:
        print(f"Warning: No annotation found for {img_name}")
        continue
    img_annotations = [ann for ann in coco_data["annotations"] if ann["image_id"] == img_id]
    boxes = [[ann["bbox"][0], ann["bbox"][1], ann["bbox"][0] + ann["bbox"][2], ann["bbox"][1] + ann["bbox"][3]] for ann in img_annotations]
    labels = [ann["category_id"] for ann in img_annotations]
    annotations.append({
        "boxes": boxes,  # Format: [[xmin, ymin, xmax, ymax], ...]
        "labels": labels  # Class labels
    })

# Filter image_paths to only include images with annotations
image_paths = [img_path for img_path, ann in zip(image_paths, annotations) if ann["boxes"] and ann["labels"]]

# Define the load_dataset function
def load_dataset(image_paths, annotations):
    dataset = []
    transform = T.ToTensor()  # Convert PIL image to tensor
    for img_path, ann in zip(image_paths, annotations):
        img = Image.open(img_path).convert("RGB")
        img_tensor = transform(img)
        target = {
            "boxes": torch.tensor(ann["boxes"], dtype=torch.float32),
            "labels": torch.tensor(ann["labels"], dtype=torch.int64)
        }
        dataset.append((img_tensor, target))
    return dataset

# Create dataset and DataLoader
from torch.utils.data import DataLoader
dataset = load_dataset(image_paths, annotations)
dataloader = DataLoader(dataset, batch_size=4, shuffle=True, collate_fn=lambda x: tuple(zip(*x)))

print(f"Loaded {len(dataset)} images with annotations.")
# Out:
# Warning: No annotation found for image_2341.jpeg
# Warning: No annotation found for image_947.jpeg
# Warning: No annotation found for image_1994.jpeg
# Warning: No annotation found for image_2711.jpeg
# Warning: No annotation found for image_1097.jpeg
# Warning: No annotation found for image_414.jpeg
# Warning: No annotation found for image_101.jpeg
# Warning: No annotation found for image_1428.jpeg
# Warning: No annotation found for image_551.jpeg
# Warning: No annotation found for image_1582.jpeg
# Warning: No annotation found for image_1078.jpeg
# Warning: No annotation found for image_802.jpeg
# Warning: No annotation found for image_2204.jpeg
# Warning: No annotation found for image_2654.jpeg
# Warning: No annotation found for image_2984.jpeg
# Warning: No annotation found for image_678.jpeg
# Warning: No annotation found for image_382.jpeg
# Warning: No annotation found for image_1351.jpeg
# Warning: No annotation found for image_228.jpeg
# Warning: No annotation found for image_1701.jpeg
# Warning: No annotation found for image_2087.jpeg
# Warning: No annotation found for image_33.jpeg
# Warning: No annotation found for image_2438.jpeg
# Warning: No annotation found for image_2068.jpeg
# Warning: No annotation found for image_2592.jpeg
# Warning: No annotation found for image_1214.jpeg

# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 60
#      58 from torch.utils.data import DataLoader
#      59 dataset = load_dataset(image_paths, annotations)
# ---> 60 dataloader = DataLoader(dataset, batch_size=4, shuffle=True, collate_fn=lambda x: tuple(zip(*x)))
#      62 print(f"Loaded {len(dataset)} images with annotations.")
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/torch/utils/data/dataloader.py:350, in DataLoader.__init__(self, dataset, batch_size, shuffle, sampler, batch_sampler, num_workers, collate_fn, pin_memory, drop_last, timeout, worker_init_fn, multiprocessing_context, generator, prefetch_factor, persistent_workers, pin_memory_device)
#     348 else:  # map-style
#     349     if shuffle:
# --> 350         sampler = RandomSampler(dataset, generator=generator)  # type: ignore[arg-type]
#     351     else:
#     352         sampler = SequentialSampler(dataset)  # type: ignore[arg-type]
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/torch/utils/data/sampler.py:143, in RandomSampler.__init__(self, data_source, replacement, num_samples, generator)
#     140     raise TypeError(f"replacement should be a boolean value, but got replacement={self.replacement}")
#     142 if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# --> 143     raise ValueError(f"num_samples should be a positive integer value, but got num_samples={self.num_samples}")
#
# ValueError: num_samples should be a positive integer value, but got num_samples=0

# %%
import os
import random
import torch
from PIL import Image
import torchvision.transforms as T
import json
import torchvision
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torchvision.models.detection.faster_rcnn import FasterRCNN_ResNet50_FPN_Weights
from torch.utils.data import DataLoader

# Set random seed for reproducibility
random.seed(42)
torch.manual_seed(42)

# Define the path to your furniture folder
downloads_path = os.path.expanduser("~/Downloads/furniture")  # Adjust for Windows: r"C:\Users\<YourUsername>\Downloads\furniture"

# Get list of image paths from all subfolders
image_paths = []
subfolders = ["cabinets,cupboards,etc", "chair", "fridge", "table", "tv"]
for subfolder in subfolders:
    subfolder_path = os.path.join(downloads_path, subfolder)
    for fname in os.listdir(subfolder_path):
        if fname.lower().endswith((".jpg", ".png", ".jpeg", ".jpe")):
            image_paths.append(os.path.join(subfolder_path, fname))

# Select one random image from each subfolder (total 5 images)
selected_image_paths = []
for subfolder in subfolders:
    subfolder_path = os.path.join(downloads_path, subfolder)
    subfolder_images = [p for p in image_paths if subfolder in p]
    if subfolder_images:
        selected_image_paths.append(random.choice(subfolder_images))

# Debugging: Print selected image paths
print("Selected image paths:")
for img_path in selected_image_paths:
    print(img_path)

# Create dummy annotations
# Categories: 1=cabinets, 2=chair, 3=fridge, 4=table, 5=tv
categories = [
    {"id": 1, "name": "cabinets"},
    {"id": 2, "name": "chair"},
    {"id": 3, "name": "fridge"},
    {"id": 4, "name": "table"},
    {"id": 5, "name": "tv"}
]

# Generate dummy COCO-format annotations
coco_data = {
    "images": [],
    "annotations": [],
    "categories": categories
}

for idx, img_path in enumerate(selected_image_paths):
    # Get image dimensions
    img = Image.open(img_path).convert("RGB")
    width, height = img.size
    
    # Add image metadata
    relative_path = os.path.join(os.path.basename(os.path.dirname(img_path)), os.path.basename(img_path))
    # Normalize the path separator and extension
    relative_path = relative_path.replace(os.sep, "/").lower().replace(".jpe", ".jpeg")
    coco_data["images"].append({
        "id": idx + 1,
        "file_name": relative_path,
        "width": width,
        "height": height
    })
    
    # Add a dummy bounding box (e.g., center of the image, 100x100 pixels)
    box = [width/2 - 50, height/2 - 50, 100, 100]  # [x, y, width, height]
    category_id = subfolders.index(os.path.basename(os.path.dirname(img_path))) + 1
    coco_data["annotations"].append({
        "image_id": idx + 1,
        "bbox": box,
        "category_id": category_id,
        "id": idx + 1
    })

# Debugging: Print the file names in coco_data['images']
print("\nFile names in coco_data['images']:")
for item in coco_data["images"]:
    print(item["file_name"])

# Map annotations to images
annotations = []
for img_path in selected_image_paths:
    relative_path = os.path.join(os.path.basename(os.path.dirname(img_path)), os.path.basename(img_path))
    relative_path = relative_path.replace(os.sep, "/").lower().replace(".jpe", ".jpeg")
    print(f"\nTrying to match: {relative_path}")
    
    img_id = next((item["id"] for item in coco_data["images"] if item["file_name"].lower() == relative_path), None)
    if img_id is None:
        print(f"Warning: No match found for {relative_path}")
        continue
    img_annotations = [ann for ann in coco_data["annotations"] if ann["image_id"] == img_id]
    boxes = [[ann["bbox"][0], ann["bbox"][1], ann["bbox"][0] + ann["bbox"][2], ann["bbox"][1] + ann["bbox"][3]] for ann in img_annotations]
    labels = [ann["category_id"] for ann in img_annotations]
    annotations.append({
        "boxes": boxes,
        "labels": labels
    })

# Filter image_paths to only include images with annotations
selected_image_paths = [img_path for img_path, ann in zip(selected_image_paths, annotations) if ann["boxes"] and ann["labels"]]

# Define the load_dataset function
def load_dataset(image_paths, annotations):
    dataset = []
    transform = T.ToTensor()
    for img_path, ann in zip(image_paths, annotations):
        img = Image.open(img_path).convert("RGB")
        img_tensor = transform(img)
        target = {
            "boxes": torch.tensor(ann["boxes"], dtype=torch.float32),
            "labels": torch.tensor(ann["labels"], dtype=torch.int64)
        }
        dataset.append((img_tensor, target))
    return dataset

# Create dataset and DataLoader
dataset = load_dataset(selected_image_paths, annotations)
dataloader = DataLoader(dataset, batch_size=2, shuffle=True, collate_fn=lambda x: tuple(zip(*x)))

# Load Faster R-CNN model with updated weights parameter
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = fasterrcnn_resnet50_fpn(weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT)
num_classes = 6  # 5 classes + background
in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = torchvision.models.detection.faster_rcnn.FastRCNNPredictor(in_features, num_classes)
model = model.to(device)

# Training setup
model.train()
optimizer = torch.optim.SGD(model.parameters(), lr=0.005, momentum=0.9, weight_decay=0.0005)
num_epochs = 5

# Training loop
for epoch in range(num_epochs):
    for images, targets in dataloader:
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())
        optimizer.zero_grad()
        losses.backward()
        optimizer.step()
    print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {losses.item()}")

print("Training completed.")
# Out:
# Selected image paths:
# /Users/skyzhao/Downloads/furniture/cabinets,cupboards,etc/image_226.jpeg
# /Users/skyzhao/Downloads/furniture/chair/image_1599.jpeg
# /Users/skyzhao/Downloads/furniture/fridge/image_1202.jpeg
# /Users/skyzhao/Downloads/furniture/table/image_1638.jpeg
# /Users/skyzhao/Downloads/furniture/tv/image_2214.jpeg
#
# File names in coco_data['images']:
# cabinets,cupboards,etc/image_226.jpegg
# chair/image_1599.jpegg
# fridge/image_1202.jpegg
# table/image_1638.jpegg
# tv/image_2214.jpegg
#
# Trying to match: cabinets,cupboards,etc/image_226.jpegg
#
# Trying to match: chair/image_1599.jpegg
#
# Trying to match: fridge/image_1202.jpegg
#
# Trying to match: table/image_1638.jpegg
#
# Trying to match: tv/image_2214.jpegg
# Epoch 1/5, Loss: 0.4183807373046875
# Epoch 2/5, Loss: 0.6392212510108948
# Epoch 3/5, Loss: 0.44014203548431396
# Epoch 4/5, Loss: 0.29586315155029297
# Epoch 5/5, Loss: 0.3235889673233032
# Training completed.

# %%
import os
import random
import torch
from PIL import Image
import torchvision.transforms as T
import json
import torchvision
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torchvision.models.detection.faster_rcnn import FasterRCNN_ResNet50_FPN_Weights
from torch.utils.data import DataLoader
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval

# Set random seed for reproducibility
random.seed(42)
torch.manual_seed(42)

# Define the path to your furniture folder
downloads_path = os.path.expanduser("~/Downloads/furniture")  # Adjust for Windows: r"C:\Users\<YourUsername>\Downloads\furniture"

# Get list of image paths from all subfolders
image_paths = []
subfolders = ["cabinets,cupboards,etc", "chair", "fridge", "table", "tv"]
for subfolder in subfolders:
    subfolder_path = os.path.join(downloads_path, subfolder)
    for fname in os.listdir(subfolder_path):
        if fname.lower().endswith((".jpg", ".png", ".jpeg", ".jpe")):
            image_paths.append(os.path.join(subfolder_path, fname))

# Select one random image from each subfolder (total 5 images)
selected_image_paths = []
for subfolder in subfolders:
    subfolder_path = os.path.join(downloads_path, subfolder)
    subfolder_images = [p for p in image_paths if subfolder in p]
    if subfolder_images:
        selected_image_paths.append(random.choice(subfolder_images))

# Split into training (4 images) and testing (1 image)
random.shuffle(selected_image_paths)
train_image_paths = selected_image_paths[:4]
test_image_paths = selected_image_paths[4:]

# Create dummy annotations
categories = [
    {"id": 1, "name": "cabinets"},
    {"id": 2, "name": "chair"},
    {"id": 3, "name": "fridge"},
    {"id": 4, "name": "table"},
    {"id": 5, "name": "tv"}
]

# Generate dummy COCO-format annotations for training and testing
coco_data = {"images": [], "annotations": [], "categories": categories}
coco_data_test = {"images": [], "annotations": [], "categories": categories}

# Training annotations
for idx, img_path in enumerate(train_image_paths):
    img = Image.open(img_path).convert("RGB")
    width, height = img.size
    relative_path = os.path.join(os.path.basename(os.path.dirname(img_path)), os.path.basename(img_path))
    relative_path = relative_path.replace(os.sep, "/").lower().replace(".jpe", ".jpeg")
    coco_data["images"].append({
        "id": idx + 1,
        "file_name": relative_path,
        "width": width,
        "height": height
    })
    box = [width/2 - 50, height/2 - 50, 100, 100]  # Dummy box
    category_id = subfolders.index(os.path.basename(os.path.dirname(img_path))) + 1
    coco_data["annotations"].append({
        "image_id": idx + 1,
        "bbox": box,
        "category_id": category_id,
        "id": idx + 1,
        "iscrowd": 0  # Added iscrowd field
    })

# Testing annotations
for idx, img_path in enumerate(test_image_paths):
    img = Image.open(img_path).convert("RGB")
    width, height = img.size
    relative_path = os.path.join(os.path.basename(os.path.dirname(img_path)), os.path.basename(img_path))
    relative_path = relative_path.replace(os.sep, "/").lower().replace(".jpe", ".jpeg")
    coco_data_test["images"].append({
        "id": idx + 1,
        "file_name": relative_path,
        "width": width,
        "height": height
    })
    box = [width/2 - 50, height/2 - 50, 100, 100]  # Dummy box
    category_id = subfolders.index(os.path.basename(os.path.dirname(img_path))) + 1
    coco_data_test["annotations"].append({
        "image_id": idx + 1,
        "bbox": box,
        "category_id": category_id,
        "id": idx + 1,
        "iscrowd": 0  # Added iscrowd field
    })

# Map annotations to images (training)
train_annotations = []
for img_path in train_image_paths:
    relative_path = os.path.join(os.path.basename(os.path.dirname(img_path)), os.path.basename(img_path))
    relative_path = relative_path.replace(os.sep, "/").lower().replace(".jpe", ".jpeg")
    img_id = next((item["id"] for item in coco_data["images"] if item["file_name"].lower() == relative_path), None)
    if img_id is None:
        continue
    img_annotations = [ann for ann in coco_data["annotations"] if ann["image_id"] == img_id]
    boxes = [[ann["bbox"][0], ann["bbox"][1], ann["bbox"][0] + ann["bbox"][2], ann["bbox"][1] + ann["bbox"][3]] for ann in img_annotations]
    labels = [ann["category_id"] for ann in img_annotations]
    train_annotations.append({
        "boxes": boxes,
        "labels": labels
    })

# Map annotations to images (testing)
test_annotations = []
for img_path in test_image_paths:
    relative_path = os.path.join(os.path.basename(os.path.dirname(img_path)), os.path.basename(img_path))
    relative_path = relative_path.replace(os.sep, "/").lower().replace(".jpe", ".jpeg")
    img_id = next((item["id"] for item in coco_data_test["images"] if item["file_name"].lower() == relative_path), None)
    if img_id is None:
        continue
    img_annotations = [ann for ann in coco_data_test["annotations"] if ann["image_id"] == img_id]
    boxes = [[ann["bbox"][0], ann["bbox"][1], ann["bbox"][0] + ann["bbox"][2], ann["bbox"][1] + ann["bbox"][3]] for ann in img_annotations]
    labels = [ann["category_id"] for ann in img_annotations]
    test_annotations.append({
        "boxes": boxes,
        "labels": labels
    })

# Define the load_dataset function
def load_dataset(image_paths, annotations):
    dataset = []
    transform = T.ToTensor()
    for img_path, ann in zip(image_paths, annotations):
        img = Image.open(img_path).convert("RGB")
        img_tensor = transform(img)
        target = {
            "boxes": torch.tensor(ann["boxes"], dtype=torch.float32),
            "labels": torch.tensor(ann["labels"], dtype=torch.int64)
        }
        dataset.append((img_tensor, target))
    return dataset

# Create training and testing datasets
train_dataset = load_dataset(train_image_paths, train_annotations)
test_dataset = load_dataset(test_image_paths, test_annotations)
train_dataloader = DataLoader(train_dataset, batch_size=2, shuffle=True, collate_fn=lambda x: tuple(zip(*x)))
test_dataloader = DataLoader(test_dataset, batch_size=1, shuffle=False, collate_fn=lambda x: tuple(zip(*x)))

# Load Faster R-CNN model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = fasterrcnn_resnet50_fpn(weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT)
num_classes = 6  # 5 classes + background
in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = torchvision.models.detection.faster_rcnn.FastRCNNPredictor(in_features, num_classes)
model = model.to(device)

# Training setup
model.train()
optimizer = torch.optim.SGD(model.parameters(), lr=0.005, momentum=0.9, weight_decay=0.0005)
num_epochs = 5

# Training loop
for epoch in range(num_epochs):
    for images, targets in train_dataloader:
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())
        optimizer.zero_grad()
        losses.backward()
        optimizer.step()
    print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {losses.item()}")

# Evaluation
model.eval()
predictions = []

# Run inference on test set
with torch.no_grad():
    for images, targets in test_dataloader:
        images = list(image.to(device) for image in images)
        outputs = model(images)
        for output, target in zip(outputs, targets):
            predictions.append({
                "boxes": output["boxes"].cpu(),
                "scores": output["scores"].cpu(),
                "labels": output["labels"].cpu(),
                "target_boxes": target["boxes"],
                "target_labels": target["labels"]
            })

# Save ground truth and predictions in COCO format for evaluation
coco_gt_file = os.path.join(downloads_path, "coco_gt.json")
coco_dt_file = os.path.join(downloads_path, "coco_dt.json")

with open(coco_gt_file, "w") as f:
    json.dump(coco_data_test, f)

# Format predictions in COCO detection format
coco_dt = []
for idx, pred in enumerate(predictions):
    image_id = idx + 1  # Matches the image_id in coco_data_test
    for box, score, label in zip(pred["boxes"], pred["scores"], pred["labels"]):
        box = box.tolist()
        coco_dt.append({
            "image_id": image_id,
            "category_id": int(label),
            "bbox": [box[0], box[1], box[2] - box[0], box[3] - box[1]],  # [x, y, width, height]
            "score": float(score)
        })

with open(coco_dt_file, "w") as f:
    json.dump(coco_dt, f)

# Evaluate using pycocotools
coco_gt = COCO(coco_gt_file)
coco_dt = coco_gt.loadRes(coco_dt_file)
coco_eval = COCOeval(coco_gt, coco_dt, "bbox")
coco_eval.evaluate()
coco_eval.accumulate()
coco_eval.summarize()

# Custom evaluation for precision, recall, and F1-score at IoU=0.5
def compute_metrics(predictions, iou_threshold=0.5):
    TP, FP, FN = 0, 0, 0
    for pred in predictions:
        pred_boxes = pred["boxes"]
        pred_labels = pred["labels"]
        pred_scores = pred["scores"]
        gt_boxes = pred["target_boxes"]
        gt_labels = pred["target_labels"]

        # Sort predictions by score (descending)
        sorted_indices = torch.argsort(pred_scores, descending=True)
        pred_boxes = pred_boxes[sorted_indices]
        pred_labels = pred_labels[sorted_indices]

        matched = set()
        for pred_box, pred_label in zip(pred_boxes, pred_labels):
            best_iou = 0
            best_gt_idx = -1
            for gt_idx, (gt_box, gt_label) in enumerate(zip(gt_boxes, gt_labels)):
                if gt_idx in matched or pred_label != gt_label:
                    continue
                # Compute IoU
                x1 = max(pred_box[0], gt_box[0])
                y1 = max(pred_box[1], gt_box[1])
                x2 = min(pred_box[2], gt_box[2])
                y2 = min(pred_box[3], gt_box[3])
                inter = max(0, x2 - x1) * max(0, y2 - y1)
                union = (pred_box[2] - pred_box[0]) * (pred_box[3] - pred_box[1]) + \
                        (gt_box[2] - gt_box[0]) * (gt_box[3] - gt_box[1]) - inter
                iou = inter / union if union > 0 else 0
                if iou > best_iou:
                    best_iou = iou
                    best_gt_idx = gt_idx

            if best_iou >= iou_threshold:
                TP += 1
                matched.add(best_gt_idx)
            else:
                FP += 1

        FN += len(gt_boxes) - len(matched)

    precision = TP / (TP + FP) if TP + FP > 0 else 0
    recall = TP / (TP + FN) if TP + FN > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if precision + recall > 0 else 0
    return precision, recall, f1

# Compute precision, recall, F1-score
precision, recall, f1 = compute_metrics(predictions, iou_threshold=0.5)
print(f"\nCustom Metrics at IoU=0.5:")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")

print("Evaluation completed.")
# Out:
# Epoch 1/5, Loss: 0.8243498802185059
# Epoch 2/5, Loss: 0.289709210395813
# Epoch 3/5, Loss: 0.4312184154987335
# Epoch 4/5, Loss: 0.41756078600883484
# Epoch 5/5, Loss: 0.30114883184432983
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 222
#     220 coco_dt = coco_gt.loadRes(coco_dt_file)
#     221 coco_eval = COCOeval(coco_gt, coco_dt, "bbox")
# --> 222 coco_eval.evaluate()
#     223 coco_eval.accumulate()
#     224 coco_eval.summarize()
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/pycocotools/cocoeval.py:154, in COCOeval.evaluate(self)
#     152 evaluateImg = self.evaluateImg
#     153 maxDet = p.maxDets[-1]
# --> 154 self.evalImgs = [evaluateImg(imgId, catId, areaRng, maxDet)
#     155          for catId in catIds
#     156          for areaRng in p.areaRng
#     157          for imgId in p.imgIds
#     158      ]
#     159 self._paramsEval = copy.deepcopy(self.params)
#     160 toc = time.time()
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/pycocotools/cocoeval.py:251, in COCOeval.evaluateImg(self, imgId, catId, aRng, maxDet)
#     248     return None
#     250 for g in gt:
# --> 251     if g['ignore'] or (g['area']<aRng[0] or g['area']>aRng[1]):
#     252         g['_ignore'] = 1
#     253     else:
#
# KeyError: 'area'

# %%
import os
import torch
from PIL import Image
import torchvision.transforms as transforms

# the root directory containing multiple subfolders of images
root_dir = 'furniture' 
save_dir = 'torch_imgs'  # new directory to store the tensors

transform = transforms.Compose([
    transforms.PILToTensor()
])

# go through the folders and save tensors
for subdir, _, files in os.walk(root_dir):
    for file in files:
        if file.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(subdir, file)
            try:
                image = Image.open(image_path).convert("RGB")
                img_tensor = transform(image)

                # consistent file name based on relative path
                relative_path = os.path.relpath(image_path, root_dir)
                tensor_filename = os.path.splitext(relative_path)[0] + '.pt'
                tensor_save_path = os.path.join(save_dir, tensor_filename)

                # make any necessary directories
                os.makedirs(os.path.dirname(tensor_save_path), exist_ok=True)

                # save the tensor
                torch.save(img_tensor, tensor_save_path)
                print(f"Saved tensor: {tensor_save_path}")

            except Exception as e:
                print(f"Error processing {image_path}: {e}")
# Out:
# Saved tensor: torch_imgs/chair/image_2341.pt
# Saved tensor: torch_imgs/chair/image_947.pt
# Saved tensor: torch_imgs/chair/image_1994.pt
# Saved tensor: torch_imgs/chair/image_2711.pt
# Saved tensor: torch_imgs/chair/image_1097.pt
# Saved tensor: torch_imgs/chair/image_414.pt
# Saved tensor: torch_imgs/chair/image_101.pt
# Saved tensor: torch_imgs/chair/image_1428.pt
# Saved tensor: torch_imgs/chair/image_551.pt
# Saved tensor: torch_imgs/chair/image_1582.pt
# Saved tensor: torch_imgs/chair/image_1078.pt
# Saved tensor: torch_imgs/chair/image_802.pt
# Saved tensor: torch_imgs/chair/image_2204.pt
# Saved tensor: torch_imgs/chair/image_2654.pt
# Saved tensor: torch_imgs/chair/image_2984.pt
# Saved tensor: torch_imgs/chair/image_678.pt
# Saved tensor: torch_imgs/chair/image_382.pt
# Saved tensor: torch_imgs/chair/image_1351.pt
# Saved tensor: torch_imgs/chair/image_228.pt
# Saved tensor: torch_imgs/chair/image_1701.pt
# Saved tensor: torch_imgs/chair/image_2087.pt
# Saved tensor: torch_imgs/chair/image_33.pt
# Saved tensor: torch_imgs/chair/image_2438.pt
# Saved tensor: torch_imgs/chair/image_2068.pt
# Saved tensor: torch_imgs/chair/image_2592.pt
# Saved tensor: torch_imgs/chair/image_1214.pt
# Saved tensor: torch_imgs/chair/image_697.pt
# Saved tensor: torch_imgs/chair/image_1644.pt
# Saved tensor: torch_imgs/chair/image_443.pt
# Saved tensor: torch_imgs/chair/image_1490.pt
# Saved tensor: torch_imgs/chair/image_1869.pt
# Saved tensor: torch_imgs/chair/image_2746.pt
# Saved tensor: torch_imgs/chair/image_910.pt
# Saved tensor: torch_imgs/chair/image_2316.pt
# Saved tensor: torch_imgs/chair/image_2603.pt
# Saved tensor: torch_imgs/chair/image_2253.pt
# Saved tensor: torch_imgs/chair/image_855.pt
# Saved tensor: torch_imgs/chair/image_1886.pt
# Saved tensor: torch_imgs/chair/image_506.pt
# Saved tensor: torch_imgs/chair/image_156.pt
# Saved tensor: torch_imgs/chair/image_1185.pt
# Saved tensor: torch_imgs/chair/image_64.pt
# Saved tensor: torch_imgs/chair/image_2480.pt
# Saved tensor: torch_imgs/chair/image_785.pt
# Saved tensor: torch_imgs/chair/image_1756.pt
# Saved tensor: torch_imgs/chair/image_2879.pt
# Saved tensor: torch_imgs/chair/image_1306.pt
# Saved tensor: torch_imgs/chair/image_1613.pt
# Saved tensor: torch_imgs/chair/image_2896.pt
# Saved tensor: torch_imgs/chair/image_290.pt
# Saved tensor: torch_imgs/chair/image_1243.pt
# Saved tensor: torch_imgs/chair/image_2195.pt
# Saved tensor: torch_imgs/chair/image_2300.pt
# Saved tensor: torch_imgs/chair/image_906.pt
# Saved tensor: torch_imgs/chair/image_2750.pt
# Saved tensor: torch_imgs/chair/image_1486.pt
# Saved tensor: torch_imgs/chair/image_455.pt
# Saved tensor: torch_imgs/chair/image_680.pt
# Saved tensor: torch_imgs/chair/image_1653.pt
# Saved tensor: torch_imgs/chair/image_1203.pt
# Saved tensor: torch_imgs/chair/image_2585.pt
# Saved tensor: torch_imgs/chair/image_403.pt
# Saved tensor: torch_imgs/chair/image_1080.pt
# Saved tensor: torch_imgs/chair/image_2706.pt
# Saved tensor: torch_imgs/chair/image_1829.pt
# Saved tensor: torch_imgs/chair/image_950.pt
# Saved tensor: torch_imgs/chair/image_1983.pt
# Saved tensor: torch_imgs/chair/image_2356.pt
# Saved tensor: torch_imgs/chair/image_2643.pt
# Saved tensor: torch_imgs/chair/image_2213.pt
# Saved tensor: torch_imgs/chair/image_815.pt
# Saved tensor: torch_imgs/chair/image_546.pt
# Saved tensor: torch_imgs/chair/image_1595.pt
# Saved tensor: torch_imgs/chair/image_116.pt
# Saved tensor: torch_imgs/chair/image_638.pt
# Saved tensor: torch_imgs/chair/image_1311.pt
# Saved tensor: torch_imgs/chair/image_268.pt
# Saved tensor: torch_imgs/chair/image_792.pt
# Saved tensor: torch_imgs/chair/image_1741.pt
# Saved tensor: torch_imgs/chair/image_2497.pt
# Saved tensor: torch_imgs/chair/image_73.pt
# Saved tensor: torch_imgs/chair/image_2478.pt
# Saved tensor: torch_imgs/chair/image_2182.pt
# Saved tensor: torch_imgs/chair/image_2028.pt
# Saved tensor: torch_imgs/chair/image_287.pt
# Saved tensor: torch_imgs/chair/image_1254.pt
# Saved tensor: torch_imgs/chair/image_2881.pt
# Saved tensor: torch_imgs/chair/image_1604.pt
# Saved tensor: torch_imgs/chair/image_2301.pt
# Saved tensor: torch_imgs/chair/image_907.pt
# Saved tensor: torch_imgs/chair/image_2751.pt
# Saved tensor: torch_imgs/chair/image_454.pt
# Saved tensor: torch_imgs/chair/image_1487.pt
# Saved tensor: torch_imgs/chair/image_141.pt
# Saved tensor: torch_imgs/chair/image_1192.pt
# Saved tensor: torch_imgs/chair/image_1468.pt
# Saved tensor: torch_imgs/chair/image_511.pt
# Saved tensor: torch_imgs/chair/image_1038.pt
# Saved tensor: torch_imgs/chair/image_842.pt
# Saved tensor: torch_imgs/chair/image_1891.pt
# Saved tensor: torch_imgs/chair/image_2244.pt
# Saved tensor: torch_imgs/chair/image_2614.pt
# Saved tensor: torch_imgs/chair/image_2481.pt
# Saved tensor: torch_imgs/chair/image_65.pt
# Saved tensor: torch_imgs/chair/image_1757.pt
# Saved tensor: torch_imgs/chair/image_2878.pt
# Saved tensor: torch_imgs/chair/image_784.pt
# Saved tensor: torch_imgs/chair/image_1307.pt
# Saved tensor: torch_imgs/chair/image_1612.pt
# Saved tensor: torch_imgs/chair/image_2897.pt
# Saved tensor: torch_imgs/chair/image_1242.pt
# Saved tensor: torch_imgs/chair/image_291.pt
# Saved tensor: torch_imgs/chair/image_2194.pt
# Saved tensor: torch_imgs/chair/image_1491.pt
# Saved tensor: torch_imgs/chair/image_442.pt
# Saved tensor: torch_imgs/chair/image_1868.pt
# Saved tensor: torch_imgs/chair/image_598.pt
# Saved tensor: torch_imgs/chair/image_432.pt
# Saved tensor: torch_imgs/chair/image_961.pt
# Saved tensor: torch_imgs/chair/image_2367.pt
# Saved tensor: torch_imgs/chair/image_1818.pt
# Saved tensor: torch_imgs/chair/image_2737.pt
# Saved tensor: torch_imgs/chair/image_2019.pt
# Saved tensor: torch_imgs/chair/image_2449.pt
# Saved tensor: torch_imgs/chair/image_1635.pt
# Saved tensor: torch_imgs/chair/image_1265.pt
# Saved tensor: torch_imgs/chair/image_259.pt
# Saved tensor: torch_imgs/chair/image_1770.pt
# Saved tensor: torch_imgs/chair/image_609.pt
# Saved tensor: torch_imgs/chair/image_1320.pt
# Saved tensor: torch_imgs/chair/image_42.pt
# Saved tensor: torch_imgs/chair/image_520.pt
# Saved tensor: torch_imgs/chair/image_1009.pt
# Saved tensor: torch_imgs/chair/image_170.pt
# Saved tensor: torch_imgs/chair/image_1459.pt
# Saved tensor: torch_imgs/chair/image_2625.pt
# Saved tensor: torch_imgs/chair/image_873.pt
# Saved tensor: torch_imgs/chair/image_2275.pt
# Saved tensor: torch_imgs/chair/image_2760.pt
# Saved tensor: torch_imgs/chair/image_2330.pt
# Saved tensor: torch_imgs/chair/image_936.pt
# Saved tensor: torch_imgs/chair/image_465.pt
# Saved tensor: torch_imgs/chair/image_1091.pt
# Saved tensor: torch_imgs/chair/image_412.pt
# Saved tensor: torch_imgs/chair/image_941.pt
# Saved tensor: torch_imgs/chair/image_1992.pt
# Saved tensor: torch_imgs/chair/image_2347.pt
# Saved tensor: torch_imgs/chair/image_1838.pt
# Saved tensor: torch_imgs/chair/image_2717.pt
# Saved tensor: torch_imgs/chair/image_2202.pt
# Saved tensor: torch_imgs/chair/image_804.pt
# Saved tensor: torch_imgs/chair/image_2652.pt
# Saved tensor: torch_imgs/chair/image_107.pt
# Saved tensor: torch_imgs/chair/image_557.pt
# Saved tensor: torch_imgs/chair/image_1584.pt
# Saved tensor: torch_imgs/chair/image_2081.pt
# Saved tensor: torch_imgs/chair/image_35.pt
# Saved tensor: torch_imgs/chair/image_384.pt
# Saved tensor: torch_imgs/chair/image_1357.pt
# Saved tensor: torch_imgs/chair/image_2982.pt
# Saved tensor: torch_imgs/chair/image_1707.pt
# Saved tensor: torch_imgs/chair/image_2828.pt
# Saved tensor: torch_imgs/chair/image_1212.pt
# Saved tensor: torch_imgs/chair/image_691.pt
# Saved tensor: torch_imgs/chair/image_1642.pt
# Saved tensor: torch_imgs/chair/image_2594.pt
# Saved tensor: torch_imgs/chair/image_2740.pt
# Saved tensor: torch_imgs/chair/image_2310.pt
# Saved tensor: torch_imgs/chair/image_916.pt
# Saved tensor: torch_imgs/chair/image_445.pt
# Saved tensor: torch_imgs/chair/image_1496.pt
# Saved tensor: torch_imgs/chair/image_500.pt
# Saved tensor: torch_imgs/chair/image_1029.pt
# Saved tensor: torch_imgs/chair/image_150.pt
# Saved tensor: torch_imgs/chair/image_1183.pt
# Saved tensor: torch_imgs/chair/image_1479.pt
# Saved tensor: torch_imgs/chair/image_644.pt
# Saved tensor: torch_imgs/chair/image_2812.pt
# Saved tensor: torch_imgs/chair/image_214.pt
# Saved tensor: torch_imgs/chair/image_1052.pt
# Saved tensor: torch_imgs/chair/image_1402.pt
# Saved tensor: torch_imgs/chair/image_2384.pt
# Saved tensor: torch_imgs/chair/image_982.pt
# Saved tensor: torch_imgs/chair/image_1951.pt
# ...
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_972.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2374.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_421.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1108.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1558.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_564.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_134.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2661.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2231.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_837.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_10.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1688.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1372.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1722.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1237.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2948.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1667.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_437.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2362.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_964.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2698.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2732.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_821.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2227.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2677.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1958.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_122.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_572.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1775.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1325.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2159.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_47.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2509.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_319.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1630.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_749.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1260.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2765.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_899.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_933.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2335.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_460.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1149.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1519.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_525.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_175.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2620.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2270.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_876.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_801.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2207.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2657.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1978.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_102.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_552.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1581.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1094.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_417.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2342.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_944.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1997.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2712.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1217.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_694.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2968.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1647.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_9.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2591.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2084.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_30.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2987.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_381.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1352.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1702.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_505.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_155.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1186.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2600.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2250.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_856.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1885.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2745.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_913.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2315.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_440.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1493.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1169.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1539.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2196.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_88.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_339.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1610.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2895.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_769.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_293.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1240.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_786.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1755.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1305.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2179.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_67.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2483.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2529.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1893.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_840.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2246.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1939.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2616.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1190.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_143.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_513.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1485.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_456.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2303.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_905.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2753.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1256.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_285.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2883.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1606.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2929.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2180.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_71.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2495.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1313.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1743.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_790.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1597.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_544.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_114.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2641.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2211.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_817.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2704.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1981.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_952.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2354.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_401.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1128.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1082.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1578.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2587.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_378.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1651.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_682.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_728.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1201.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1714.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1344.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_397.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2991.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2138.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_26.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2568.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2092.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2285.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1850.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_883.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_929.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1153.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_180.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1503.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1016.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1446.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_495.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1915.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2790.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2840.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1295.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_246.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_616.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2143.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2513.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2006.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2456.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_303.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2905.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1780.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_753.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1554.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_587.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1104.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2378.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2682.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1807.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2728.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2397.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1942.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_991.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_138.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1411.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_568.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1041.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2544.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2114.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1692.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_641.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1368.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_211.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1738.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2817.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_704.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2952.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1387.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_354.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2401.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2051.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1811.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2694.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_968.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1112.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_591.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1542.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1057.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1407.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_987.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1954.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2381.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2801.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_207.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_657.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1684.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2102.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2552.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2047.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2417.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_342.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1391.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2944.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_712.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1515.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_196.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1145.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2339.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_895.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2769.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1846.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2293.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2786.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1903.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_179.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_483.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1450.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_529.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1000.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2505.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2155.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_600.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1329.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_250.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1283.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2856.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1779.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_745.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_1796.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2913.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_315.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2440.pt
# Saved tensor: torch_imgs/cabinets,cupboards,etc/image_2010.pt

# %%
import os
import torch
import torchvision
from torchvision.models.detection import fasterrcnn_resnet50_fpn, FasterRCNN_ResNet50_FPN_Weights
from torchvision.transforms import functional as F
import matplotlib.pyplot as plt
import numpy as np
from torch.utils.data import IterableDataset, DataLoader

# Define IterableDataset for tensor files
class TensorIterableDataset(IterableDataset):
    def __init__(self, tensor_dir):
        self.tensor_dir = tensor_dir

    def __iter__(self):
        # Walk through the tensor directory and yield tensors
        for subdir, _, files in os.walk(self.tensor_dir):
            for file in files:
                if file.endswith('.pt'):
                    tensor_path = os.path.join(subdir, file)
                    try:
                        # Load tensor
                        img_tensor = torch.load(tensor_path)
                        
                        # Ensure tensor is in correct format (C, H, W)
                        if img_tensor.dtype == torch.uint8:
                            img_tensor = img_tensor.float() / 255.0  # Convert to float and normalize to [0, 1]
                        
                        # Normalize for pretrained model
                        img_tensor = F.normalize(img_tensor, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
                        
                        # Yield tensor and its path (for saving predictions)
                        yield img_tensor, tensor_path
                    except Exception as e:
                        print(f"Error loading {tensor_path}: {e}")

# Directory containing saved tensors
tensor_dir = 'torch_imgs'

# Create IterableDataset
dataset = TensorIterableDataset(tensor_dir)

# Create DataLoader
data_loader = DataLoader(dataset, batch_size=2, num_workers=0, collate_fn=lambda x: tuple(zip(*x)))

# Load pretrained Faster R-CNN model
model = fasterrcnn_resnet50_fpn(weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1)
model.eval()  # Set to evaluation mode
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model.to(device)

# COCO class names (for interpreting predictions)
COCO_CLASSES = [
    '__background__', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A', 'stop sign',
    'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow',
    'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack', 'umbrella', 'N/A', 'N/A',
    'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
    'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket',
    'bottle', 'N/A', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl',
    'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
    'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table',
    'N/A', 'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 
    'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A', 'book',
    'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush'
]

# Function to visualize predictions
def plot_predictions(img_tensor, predictions, save_path=None):
    img = img_tensor.permute(1, 2, 0).numpy()  # Convert CHW to HWC
    img = img * torch.tensor([0.229, 0.224, 0.225]) + torch.tensor([0.485, 0.456, 0.406])  # Denormalize
    img = np.clip(img, 0, 1)  # Ensure values are in [0, 1]
    
    plt.figure(figsize=(10, 10))
    plt.imshow(img)
    ax = plt.gca()
    
    for box, label, score in zip(predictions['boxes'], predictions['labels'], predictions['scores']):
        if score > 0.5:  # Only show predictions with confidence > 0.5
            x_min, y_min, x_max, y_max = box.cpu().numpy()
            width = x_max - x_min
            height = y_max - y_min
            rect = plt.Rectangle((x_min, y_min), width, height, linewidth=2, edgecolor='r', facecolor='none')
            ax.add_patch(rect)
            ax.text(x_min, y_min - 5, f'{COCO_CLASSES[label]}: {score:.2f}', color='red', fontsize=12, weight='bold')
    
    plt.axis('off')
    if save_path:
        plt.savefig(save_path, bbox_inches='tight')
        plt.close()
    else:
        plt.show()

# Perform inference with DataLoader
for batch_tensors, batch_paths in data_loader:
    try:
        # Move tensors to device
        batch_tensors = [t.to(device) for t in batch_tensors]
        
        # Perform inference
        with torch.no_grad():
            predictions = model(batch_tensors)  # List of prediction dicts for each image
        
        # Process each image in the batch
        for img_tensor, pred, tensor_path in zip(batch_tensors, predictions, batch_paths):
            # Print predictions
            print(f"\nProcessing {tensor_path}")
            for box, label, score in zip(pred['boxes'], pred['labels'], pred['scores']):
                if score > 0.5:  # Filter low-confidence predictions
                    print(f"Detected {COCO_CLASSES[label]} with confidence {score:.2f} at {box.cpu().numpy()}")
            
            # Visualize and save predictions
            save_path = os.path.join('predictions', os.path.relpath(tensor_path, tensor_dir).replace('.pt', '_pred.jpg'))
            os.makedirs(os.path.dirname(save_path), exist_ok=True)
            plot_predictions(img_tensor.cpu(), pred, save_path=save_path)
            print(f"Saved prediction visualization: {save_path}")

    except Exception as e:
        print(f"Error processing batch: {e}")
# Out:
# Processing torch_imgs/chair/image_2454.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_2514.pt
# Detected bench with confidence 0.86 at [ 68.61859 148.28452 114.75587 191.3078 ]
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_2897.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_2405.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_2767.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_319.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_259.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_2736.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_348.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_208.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_2676.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_1489.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_1658.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_2520.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_1598.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_2460.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_2642.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_2493.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_2910.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_2582.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_
pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_744.pt
# Detected potted plant with confidence 0.65 at [148.02025  99.04721 173.81958 136.41496]
# Detected vase with confidence 0.59 at [148.69255 109.09006 173.2078  136.20027]
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_595.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_1382.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_816.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_715.pt
# Detected traffic light with confidence 0.72 at [ 24.190783 114.7543    35.174953 148.17694 ]
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_1102.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_1042.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_956.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_1260.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_2398.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_67.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_537.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_426.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_2058.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_2118.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_1371.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_661.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_962.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_1136.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
#
# Processing torch_imgs/chair/image_1027.pt
# Error processing batch: unsupported operand type(s) for *: 'numpy.ndarray' and 'Tensor'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 102
#     100 # Perform inference
#     101 with torch.no_grad():
# --> 102     predictions = model(batch_tensors)  # List of prediction dicts for each image
#     104 # Process each image in the batch
#     105 for img_tensor, pred, tensor_path in zip(batch_tensors, predictions, batch_paths):
#     106     # Print predictions
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/torchvision/models/detection/generalized_rcnn.py:105, in GeneralizedRCNN.forward(self, images, targets)
#     103     features = OrderedDict([("0", features)])
#     104 proposals, proposal_losses = self.rpn(images, features, targets)
# --> 105 detections, detector_losses = self.roi_heads(features, proposals, images.image_sizes, targets)
#     106 detections = self.transform.postprocess(detections, images.image_sizes, original_image_sizes)  # type: ignore[operator]
#     108 losses = {}
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/torchvision/models/detection/roi_heads.py:761, in RoIHeads.forward(self, features, proposals, image_shapes, targets)
#     758     regression_targets = None
#     759     matched_idxs = None
# --> 761 box_features = self.box_roi_pool(features, proposals, image_shapes)
#     762 box_features = self.box_head(box_features)
#     763 class_logits, box_regression = self.box_predictor(box_features)
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/torchvision/ops/poolers.py:314, in MultiScaleRoIAlign.forward(self, x, boxes, image_shapes)
#     309 if self.scales is None or self.map_levels is None:
#     310     self.scales, self.map_levels = _setup_scales(
#     311         x_filtered, image_shapes, self.canonical_scale, self.canonical_level
#     312     )
# --> 314 return _multiscale_roi_align(
#     315     x_filtered,
#     316     boxes,
#     317     self.output_size,
#     318     self.sampling_ratio,
#     319     self.scales,
#     320     self.map_levels,
#     321 )
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/torchvision/ops/poolers.py:204, in _multiscale_roi_align(x_filtered, boxes, output_size, sampling_ratio, scales, mapper)
#     201 idx_in_level = torch.where(levels == level)[0]
#     202 rois_per_level = rois[idx_in_level]
# --> 204 result_idx_in_level = roi_align(
#     205     per_level_feature,
#     206     rois_per_level,
#     207     output_size=output_size,
#     208     spatial_scale=scale,
#     209     sampling_ratio=sampling_ratio,
#     210 )
#     212 if torchvision._is_tracing():
#     213     tracing_results.append(result_idx_in_level.to(dtype))
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/torchvision/ops/roi_align.py:238, in roi_align(input, boxes, output_size, spatial_scale, sampling_ratio, aligned)
#     236         return _roi_align(input, rois, spatial_scale, output_size[0], output_size[1], sampling_ratio, aligned)
#     237 _assert_has_ops()
# --> 238 return torch.ops.torchvision.roi_align(
#     239     input, rois, spatial_scale, output_size[0], output_size[1], sampling_ratio, aligned
#     240 )
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/torch/_ops.py:755, in OpOverloadPacket.__call__(self, *args, **kwargs)
#     750 def __call__(self, *args, **kwargs):
#     751     # overloading __call__ to ensure torch.ops.foo.bar()
#     752     # is still callable from JIT
#     753     # We save the function ptr as the `op` attribute on
#     754     # OpOverloadPacket to access it here.
# --> 755     return self._op(*args, **(kwargs or {}))
#
# KeyboardInterrupt:
